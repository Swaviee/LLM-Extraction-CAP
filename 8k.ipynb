# %%
import csv
import time
import requests
import json
import os
import re
import random
import xml.etree.ElementTree as ET
from datetime import datetime
import logging

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("sec_downloader.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Create output directory if it doesn't exist
output_dir = "8k_filings_json"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Configuration
TARGET_YEAR = "2024"       # Only download filings from this year
MIN_DELAY = 1.0            # Minimum delay between requests in seconds
MAX_DELAY = 3.0            # Maximum delay between requests in seconds
MAX_RETRIES = 3            # Maximum number of retries for a request

# ATOM namespace for parsing XML response
ATOM_NS = {'atom': 'http://www.w3.org/2005/Atom'}

# Configure request settings with user-agent
def get_headers(host="www.sec.gov"):
    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    email = "he431641@ucf.edu"  # REPLACE WITH YOUR ACTUAL EMAIL
    
    return {
        "User-Agent": f"{email} {user_agent}",
        "Accept": "application/xml, text/html, application/xhtml+xml, application/json",
        "Accept-Encoding": "gzip, deflate, br",
        "Host": host,
        "Connection": "keep-alive"
    }

def download_sp500_list():
    """Download current S&P 500 companies list from a reliable source"""
    logger.info("Downloading S&P 500 companies list...")
    
    try:
        # Using Wikipedia as a source for S&P 500 constituents
        url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
        response = requests.get(url, headers=get_headers(host="en.wikipedia.org"))
        
        if response.status_code != 200:
            logger.error(f"Failed to download S&P 500 list: HTTP {response.status_code}")
            return set()
        
        # Extract tickers from the Wikipedia table
        # Look for the first table with S&P 500 components
        table_pattern = r'<table[^>]*>.*?<th[^>]*>Symbol</th>.*?</table>'
        table_match = re.search(table_pattern, response.text, re.DOTALL)
        
        if not table_match:
            logger.error("Could not find S&P 500 table in Wikipedia page")
            return set()
        
        table_html = table_match.group(0)
        
        # Extract tickers from table rows
        ticker_pattern = r'<tr[^>]*>.*?<td[^>]*>(.*?)</td>'
        tickers = re.findall(ticker_pattern, table_html)
        
        # Clean up tickers (they will be in the first column of each row)
        sp500_tickers = set()
        for i, ticker in enumerate(tickers):
            # Skip header row
            if i == 0:
                continue
                
            # Clean ticker (remove HTML tags and whitespace)
            clean_ticker = re.sub(r'<[^>]*>', '', ticker).strip().upper()
            if clean_ticker:
                sp500_tickers.add(clean_ticker)
        
        logger.info(f"Downloaded {len(sp500_tickers)} S&P 500 tickers")
        return sp500_tickers
        
    except Exception as e:
        logger.error(f"Error downloading S&P 500 list: {str(e)}")
        return set()

def load_companies():
    """Load company information from sec_companies2.csv"""
    companies = []
    
    try:
        with open('sec_companies2.csv', 'r') as f:
            reader = csv.DictReader(f)
            for row in reader:
                # Extract CIK and other information
                cik = row.get('CIK', '')
                ticker = row.get('Ticker', '').upper()
                name = row.get('Company Name', '')
                
                # Get the count of 8-Ks to download, default to 4 if not specified
                try:
                    count = int(row.get('Count', '4'))
                except (ValueError, TypeError):
                    count = 4
                
                if cik and (ticker or name):  # Ensure we have at least CIK and either ticker or name
                    # Clean up CIK (remove leading zeros for the URL)
                    clean_cik = str(cik).lstrip('0')
                    
                    companies.append({
                        'cik': clean_cik, 
                        'ticker': ticker,
                        'name': name,
                        'count': count,
                        'is_sp500': False  # Will be updated later
                    })
        
        logger.info(f"Loaded {len(companies)} companies from sec_companies2.csv")
        return companies
    
    except FileNotFoundError:
        logger.error(f"File not found: sec_companies2.csv")
        # Create a sample CSV file format to help the user
        with open('sec_companies2_sample.csv', 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['CIK', 'Ticker', 'Company Name', 'Count'])
            writer.writerow(['1318605', 'TSLA', 'Tesla Inc', '4'])
            writer.writerow(['320193', 'AAPL', 'Apple Inc', '4'])
        logger.info(f"Created a sample file 'sec_companies2_sample.csv' for reference")
        return []
    except Exception as e:
        logger.error(f"Error loading companies: {str(e)}")
        return []

def sort_companies_with_sp500_priority(companies):
    """Sort companies list so S&P 500 companies come first"""
    # Download S&P 500 tickers
    sp500_tickers = download_sp500_list()
    
    # If we couldn't get the S&P 500 list, use a fallback list of major companies
    if not sp500_tickers:
        logger.warning("Using fallback S&P 500 list (top companies only)")
        fallback_sp500 = {
            "AAPL", "MSFT", "AMZN", "NVDA", "GOOGL", "GOOG", "META", "BRK.B", 
            "LLY", "TSLA", "V", "UNH", "JPM", "XOM", "AVGO", "MA", "PG", "HD", 
            "COST", "MRK", "CVX", "ABBV", "KO", "PEP", "WMT", "ACN", "ADBE", 
            "MCD", "BAC", "CRM", "TXN", "LIN", "AMD", "TMO", "CSCO", "ABT", 
            "DHR", "CMCSA", "NKE", "INTC", "NFLX", "VZ", "PM", "WFC", "DIS", 
            "COP", "INTU", "IBM", "ORCL", "QCOM", "SPGI", "CAT", "GE", "HON", 
            "AMGN", "LOW", "AXP", "BA", "DE", "UPS", "RTX", "MS", "TJX", "GS", 
            "BLK", "PLD", "AMAT", "SBUX", "MDT", "CVS", "GILD", "SYK", "AMT", 
            "MDLZ", "ELV", "C", "ADI", "BKNG", "ADP", "ISRG", "MMC", "LRCX", 
            "TGT", "REGN", "VRTX", "CI", "SO", "PGR", "ZTS", "BSX", "CB", "MO", 
            "BDX", "DUK", "ETN", "SCHW", "SLB"
        }
        sp500_tickers = fallback_sp500
    
    # Mark companies that are in the S&P 500
    for company in companies:
        if company['ticker'] in sp500_tickers:
            company['is_sp500'] = True
    
    # Sort companies - S&P 500 first, then others
    sp500_companies = [c for c in companies if c['is_sp500']]
    other_companies = [c for c in companies if not c['is_sp500']]
    
    # Log the results
    logger.info(f"Found {len(sp500_companies)} S&P 500 companies in the input file")
    logger.info(f"Found {len(other_companies)} non-S&P 500 companies in the input file")
    
    # Return the combined sorted list
    return sp500_companies + other_companies

def get_processed_companies():
    """Get already processed companies to avoid duplicates"""
    processed = set()
    if os.path.exists('processed_companies.txt'):
        with open('processed_companies.txt', 'r') as f:
            for line in f:
                processed.add(line.strip())
    return processed

def save_processed_company(cik):
    """Save a company as processed"""
    with open('processed_companies.txt', 'a') as f:
        f.write(f"{cik}\n")

def extract_accession_from_url(url):
    """Extract accession number from URL patterns common in SEC filings"""
    # Pattern 1: /data/CIK/ACCESSION/
    pattern1 = r'/data/\d+/(\d{10}-\d{2}-\d{6})/'
    match = re.search(pattern1, url)
    if match:
        return match.group(1)
    
    # Pattern 2: /ACCESSION-index.htm
    pattern2 = r'/(\d{10}-\d{2}-\d{6})-index\.html?'
    match = re.search(pattern2, url)
    if match:
        return match.group(1)
    
    # Pattern 3: Look for /XXXXXXXXXX/XXXXXXXXXX/XXXXXXXXXX/ pattern
    # This is typically /CIK/ACCESSION/ but without dashes
    pattern3 = r'/(\d{10})/(\d{10})/'
    match = re.search(pattern3, url)
    if match:
        # Format as standard accession with dashes
        acc = match.group(2)
        if len(acc) == 10:
            # Probably not an accession
            return None
            
        # Try to format as accession XXXXXXXXXX-XX-XXXXXX
        if len(acc) >= 12:
            return f"{acc[0:10]}-{acc[10:12]}-{acc[12:]}"
    
    # Pattern 4: /ACCESSION-index in the URL path
    pattern4 = r'/(\d{10}\d{2}\d{6})-index'
    match = re.search(pattern4, url)
    if match:
        acc = match.group(1)
        if len(acc) >= 18:
            return f"{acc[0:10]}-{acc[10:12]}-{acc[12:18]}"
    
    return None

def get_filings_atom(company):
    """Get 8-K filings for a company using the SEC's Atom feed"""
    cik = company['cik']
    ticker = company['ticker']
    company_name = company['name']
    count = company['count']
    is_sp500 = company['is_sp500']
    
    search_url = f"https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={cik}&type=8-K&count={count}&output=atom"
    
    sp500_marker = "[S&P 500]" if is_sp500 else ""
    logger.info(f"Requesting ATOM feed for {ticker or company_name} {sp500_marker} (CIK {cik})...")
    
    # Random delay before request
    time.sleep(random.uniform(MIN_DELAY, MAX_DELAY))
    
    try:
        response = requests.get(search_url, headers=get_headers())
        
        # Handle HTTP status codes
        if response.status_code != 200:
            logger.error(f"Error: HTTP {response.status_code} for {ticker or company_name}")
            return []
        
        # Save raw response for debugging if needed
        debug_dir = "debug_xml"
        if not os.path.exists(debug_dir):
            os.makedirs(debug_dir)
        with open(f"{debug_dir}/{cik}_atom_response.xml", "w", encoding="utf-8") as f:
            f.write(response.text)
        
        # Check if the response is XML
        if "<?xml" not in response.text[:100]:
            logger.warning(f"Response for {ticker or company_name} does not appear to be XML")
            return []
        
        # Parse XML
        try:
            root = ET.fromstring(response.content)
            
            # Find all entries (filings)
            entries = root.findall('./atom:entry', ATOM_NS)
            
            # Process entries
            filings = []
            for i, entry in enumerate(entries):
                # Extract filing information using proper namespace
                title_elem = entry.find('./atom:title', ATOM_NS)
                updated_elem = entry.find('./atom:updated', ATOM_NS)
                link_elem = entry.find('./atom:link', ATOM_NS)
                summary_elem = entry.find('./atom:summary', ATOM_NS)
                
                # Extract text from elements
                title_text = title_elem.text if title_elem is not None else "No Title"
                updated_text = updated_elem.text if updated_elem is not None else ""
                
                # Format the date (remove time part)
                filing_date = updated_text.split('T')[0] if updated_text else "No Date"
                
                # Skip filings that are not from the target year
                if not filing_date.startswith(TARGET_YEAR):
                    continue
                
                # Get link from attributes
                link_href = link_elem.get('href') if link_elem is not None else ""
                
                # Extract description from summary
                summary_text = summary_elem.text if summary_elem is not None else ""
                
                # Parse the filing date from summary if not available from updated
                if filing_date == "No Date" and summary_text:
                    date_match = re.search(r'<b>Filed:</b>\s+(\d{4}-\d{2}-\d{2})', summary_text)
                    if date_match:
                        filing_date = date_match.group(1)
                        # Skip if not from target year
                        if not filing_date.startswith(TARGET_YEAR):
                            continue
                
                # Extract the accession number from several possible sources
                accession_number = None
                
                # Method 1: From the summary text
                if summary_text:
                    accession_match = re.search(r'Accession Number:\s+(\d{10}-\d{2}-\d{6})', summary_text)
                    if accession_match:
                        accession_number = accession_match.group(1)
                
                # Method 2: From the title text
                if not accession_number and title_text:
                    title_match = re.search(r'(\d{10}-\d{2}-\d{6})', title_text)
                    if title_match:
                        accession_number = title_match.group(1)
                
                # Method 3: From the link URL
                if not accession_number and link_href:
                    accession_number = extract_accession_from_url(link_href)
                
                # Create a filing ID even if we don't have an accession number
                filing_id = accession_number if accession_number else f"filing_{i}"
                
                if link_href and filing_date != "No Date":
                    filings.append({
                        'title': title_text,
                        'date': filing_date,
                        'url': f"https://www.sec.gov{link_href}" if link_href.startswith('/') else link_href,
                        'summary': summary_text,
                        'accession_number': accession_number,
                        'filing_id': filing_id,
                        'cik': cik,
                        'ticker': ticker,
                        'company_name': company_name,
                        'is_sp500': is_sp500
                    })
            
            # Sort filings by date (newer first)
            filings.sort(key=lambda x: x['date'], reverse=True)
            
            sp500_marker = "[S&P 500]" if is_sp500 else ""
            logger.info(f"Found {len(filings)} 8-K filings from {TARGET_YEAR} for {ticker or company_name} {sp500_marker}")
            return filings
            
        except ET.ParseError as pe:
            logger.error(f"XML parsing error for {ticker or company_name}: {str(pe)}")
            return []
            
    except Exception as e:
        logger.error(f"Error with {ticker or company_name}: {str(e)}")
        return []

def get_filing_details(filing):
    """Get the filing details from the SEC website"""
    filing_url = filing['url']
    cik = filing['cik']
    ticker = filing['ticker']
    company_name = filing['company_name']
    filing_date = filing['date']
    filing_id = filing.get('filing_id', 'unknown')
    accession_number = filing.get('accession_number')
    is_sp500 = filing.get('is_sp500', False)
    
    # Debug information
    sp500_marker = "[S&P 500]" if is_sp500 else ""
    logger.info(f"Processing filing data for {filing_date} - {ticker or company_name} {sp500_marker}")
    logger.info(f"  URL: {filing_url}")
    logger.info(f"  Accession Number: {accession_number}")
    
    # Try to extract accession number from URL if not already available
    if not accession_number:
        accession_number = extract_accession_from_url(filing_url)
        if accession_number:
            logger.info(f"  Extracted accession number from URL: {accession_number}")
    
    # Generate a unique, clean identifier for this filing (for the filename)
    if accession_number:
        # Use accession number if available, removing dashes
        clean_id = accession_number.replace('-', '')
    else:
        # Use a generated ID if no accession number
        clean_id = filing_id.replace(' ', '_').replace('-', '_')
    
    # Random delay before request
    time.sleep(random.uniform(MIN_DELAY, MAX_DELAY))
    
    try:
        # First get the filing detail page
        detail_response = requests.get(filing_url, headers=get_headers())
        
        if detail_response.status_code != 200:
            logger.error(f"Failed to access filing detail page: HTTP {detail_response.status_code}")
            return None, None
        
        # Save the detail page for debugging
        debug_dir = "debug_html"
        if not os.path.exists(debug_dir):
            os.makedirs(debug_dir)
        with open(f"{debug_dir}/{ticker or cik}_{clean_id}_detail.html", "w", encoding="utf-8") as f:
            f.write(detail_response.text)
        
        # Try to extract accession number from detail page if not already available
        if not accession_number:
            detail_text = detail_response.text
            
            # Method 1: Look for accession number in the text
            acc_match = re.search(r'Accession Number:\s*(\d{10}-\d{2}-\d{6})', detail_text)
            if acc_match:
                accession_number = acc_match.group(1)
                clean_id = accession_number.replace('-', '')
                logger.info(f"  Found accession number from detail page: {accession_number}")
            
            # Method 2: Look for it in the URL of document links
            if not accession_number:
                doc_links = re.findall(r'href="([^"]+/\d{10}-\d{2}-\d{6}[^"]+)"', detail_text)
                if doc_links:
                    for link in doc_links:
                        extracted = extract_accession_from_url(link)
                        if extracted:
                            accession_number = extracted
                            clean_id = accession_number.replace('-', '')
                            logger.info(f"  Found accession number from document link: {accession_number}")
                            break
            
            # Method 3: Look for accession number pattern in the page content
            if not accession_number:
                # Look for any 10-2-6 digit pattern that might be an accession number
                acc_pattern = re.findall(r'(\d{10}-\d{2}-\d{6})', detail_text)
                if acc_pattern:
                    accession_number = acc_pattern[0]
                    clean_id = accession_number.replace('-', '')
                    logger.info(f"  Found accession number pattern in detail page: {accession_number}")
        
        # Try to get the filing text in different ways
        submissions = []
        
        # Method 1: Try the standard .txt submission file if we have an accession number
        if accession_number:
            clean_accession = accession_number.replace('-', '')
            txt_url = f"https://www.sec.gov/Archives/edgar/data/{cik}/{clean_accession}/{accession_number}.txt"
            
            time.sleep(random.uniform(MIN_DELAY, MAX_DELAY))
            
            txt_response = requests.get(txt_url, headers=get_headers())
            
            if txt_response.status_code == 200:
                logger.info(f"  Successfully retrieved full text submission")
                submissions.append({
                    "type": "full_submission",
                    "url": txt_url,
                    "text": txt_response.text
                })
        
        # Method 2: Try to get individual document HTML files from the detail page
        document_links = extract_document_links(detail_response.text, cik)
        
        for doc in document_links:
            doc_url = doc['url']
            doc_type = doc['text']
            
            if '8-K' in doc_type or 'EX-' in doc_type.upper():
                time.sleep(random.uniform(MIN_DELAY, MAX_DELAY))
                
                try:
                    doc_response = requests.get(doc_url, headers=get_headers())
                    
                    if doc_response.status_code == 200:
                        logger.info(f"  Retrieved document: {doc_type}")
                        submissions.append({
                            "type": doc_type,
                            "url": doc_url,
                            "text": doc_response.text
                        })
                except Exception as e:
                    logger.warning(f"  Error getting document {doc_type}: {str(e)}")
        
        # Create our response structure
        if submissions:
            # Create a structured JSON with the filing data and all documents
            filing_data = {
                "companyName": company_name,
                "cik": cik,
                "ticker": ticker,
                "filingDate": filing_date,
                "formType": "8-K",
                "accessionNumber": accession_number if accession_number else "unknown",
                "filingUrl": filing_url,
                "isSP500": is_sp500,
                "documents": []
            }
            
            # Process each submission
            for sub in submissions:
                # Extract document type
                doc_type = sub.get("type", "UNKNOWN")
                
                # If this is the full submission, extract the individual document sections
                if doc_type == "full_submission":
                    sections = extract_sections(sub.get("text", ""))
                    for section in sections:
                        filing_data["documents"].append({
                            "type": section.get("type", "UNKNOWN"),
                            "description": section.get("description", ""),
                            "text": section.get("text", ""),
                            "url": sub.get("url", "")
                        })
                else:
                    # Add this as a separate document
                    filing_data["documents"].append({
                        "type": doc_type,
                        "description": "",
                        "text": sub.get("text", ""),
                        "url": sub.get("url", "")
                    })
            
            return filing_data, clean_id
        else:
            # If we couldn't get any documents, use the detail page
            logger.warning(f"Could not retrieve any documents. Using detail page only.")
            
            filing_data = {
                "companyName": company_name,
                "cik": cik,
                "ticker": ticker,
                "filingDate": filing_date,
                "formType": "8-K",
                "accessionNumber": accession_number if accession_number else "unknown",
                "filingUrl": filing_url,
                "isSP500": is_sp500,
                "detailPage": detail_response.text,
                "documentLinks": document_links
            }
            
            return filing_data, clean_id
        
    except Exception as e:
        logger.error(f"Error getting filing details: {str(e)}")
        return None, None

def extract_document_links(detail_page, cik):
    """Extract document links from the detail page"""
    links = []
    
    # Pattern 1: Look for document table rows with links
    doc_pattern = re.compile(r'<tr[^>]*>.*?<td[^>]*>.*?<a[^>]*href="([^"]+)"[^>]*>([^<]+)</a>.*?</tr>', re.DOTALL)
    matches = doc_pattern.findall(detail_page)
    
    for href, text in matches:
        # Clean up the text and href
        text = text.strip()
        href = href.strip()
        
        # Check if this is likely a document link
        if ('8-K' in text or 'EX-' in text.upper() or 'ex-' in text) and href:
            # Make the URL absolute if it's relative
            full_url = f"https://www.sec.gov{href}" if href.startswith('/') else href
            links.append({
                "text": text,
                "url": full_url
            })
    
    # Pattern 2: Look for HTML document links in any context
    html_pattern = re.compile(r'href=["\']([^"\']*?\.htm(?:l)?)["\']', re.IGNORECASE)
    html_matches = html_pattern.findall(detail_page)
    
    for href in html_matches:
        href = href.strip()
        if href and '8-K' in href.upper() or 'EX-' in href.upper():
            # Make the URL absolute if it's relative
            full_url = f"https://www.sec.gov{href}" if href.startswith('/') else href
            # Generate a description based on the URL
            description = "8-K"
            if "ex-" in href.lower() or "exhibit" in href.lower():
                description = f"Exhibit {href.split('/')[-1]}"
            
            # Check if it's already in the links
            if not any(link["url"] == full_url for link in links):
                links.append({
                    "text": description,
                    "url": full_url
                })
    
    return links

def extract_sections(full_text):
    """Extract document sections from the full text submission"""
    sections = []
    
    # Look for <DOCUMENT> tags
    doc_pattern = re.compile(r'<DOCUMENT>(.*?)</DOCUMENT>', re.DOTALL)
    doc_matches = doc_pattern.findall(full_text)
    
    for doc_text in doc_matches:
        # Try to extract document type
        type_match = re.search(r'<TYPE>(.*?)</TYPE>', doc_text)
        doc_type = type_match.group(1) if type_match else "UNKNOWN"
        
        # Try to extract document description
        desc_match = re.search(r'<DESCRIPTION>(.*?)</DESCRIPTION>', doc_text)
        description = desc_match.group(1) if desc_match else ""
        
        # Try to extract document text
        text_match = re.search(r'<TEXT>(.*?)</TEXT>', doc_text, re.DOTALL)
        text = text_match.group(1) if text_match else doc_text
        
        sections.append({
            "type": doc_type,
            "description": description,
            "text": text
        })
    
    # If no sections found, try to look for exhibit markers
    if not sections:
        # Common exhibit markers in 8-K filings
        exhibit_markers = [
            r'EXHIBIT\s+(\d+\.\d+)',
            r'ITEM\s+(\d+\.\d+)'
        ]
        
        for marker in exhibit_markers:
            pattern = re.compile(marker, re.IGNORECASE)
            matches = list(pattern.finditer(full_text))
            
            # Process each match to extract sections
            for i, match in enumerate(matches):
                section_type = match.group(0)
                start_pos = match.start()
                
                # Determine end position (next match or end of text)
                if i < len(matches) - 1:
                    end_pos = matches[i+1].start()
                else:
                    end_pos = len(full_text)
                
                # Extract the section text
                section_text = full_text[start_pos:end_pos].strip()
                
                sections.append({
                    "type": section_type,
                    "description": "",
                    "text": section_text
                })
    
    return sections

def main():
    # Timestamp the start of the process
    start_time = datetime.now()
    logger.info(f"Process started at {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
    
    # Load companies from the CSV file
    companies = load_companies()
    
    if not companies:
        logger.error("No companies loaded. Check the sec_companies2.csv file.")
        return
    
    # Sort companies so S&P 500 companies are processed first
    companies = sort_companies_with_sp500_priority(companies)
    
    # Get already processed companies
    processed_companies = get_processed_companies()
    logger.info(f"Found {len(processed_companies)} already processed companies")
    
    # Create or append to output file for tracking
    file_exists = os.path.exists('8k_filings.csv')
    mode = 'a' if file_exists else 'w'
    
    with open('8k_filings.csv', mode, newline='') as outfile:
        writer = csv.writer(outfile)
        
        # Write header if new file
        if not file_exists:
            writer.writerow(['CIK', 'Ticker', 'Company Name', 'Filing Date', 'Form Type', 'Accession Number', 'Local File Path', 'Is S&P 500'])
        
        # Track overall stats
        total_downloaded = 0
        companies_processed = 0
        sp500_processed = 0
        other_processed = 0
        
        # Process each company
        for company_idx, company in enumerate(companies):
            cik = company['cik']
            ticker = company['ticker']
            company_name = company['name']
            is_sp500 = company['is_sp500']
            
            # Skip if already processed
            if cik in processed_companies:
                logger.info(f"Skipping {ticker or company_name} (CIK {cik}) - Already processed")
                companies_processed += 1
                if is_sp500:
                    sp500_processed += 1
                else:
                    other_processed += 1
                continue
            
            sp500_marker = "[S&P 500]" if is_sp500 else ""
            logger.info(f"\nProcessing {ticker or company_name} {sp500_marker} (CIK {cik})")
            
            # Try to get filings for this company
            retry_count = 0
            filings = []
            
            while retry_count < MAX_RETRIES and not filings:
                if retry_count > 0:
                    logger.info(f"Retry {retry_count}/{MAX_RETRIES} for {ticker or company_name}")
                    time.sleep(random.uniform(5.0, 10.0))
                
                filings = get_filings_atom(company)
                retry_count += 1
            
            # If we still don't have filings after retries, skip this company
            if not filings:
                logger.warning(f"No filings found for {ticker or company_name} after {MAX_RETRIES} attempts")
                # Mark as processed anyway to avoid repeated attempts
                save_processed_company(cik)
                companies_processed += 1
                if is_sp500:
                    sp500_processed += 1
                else:
                    other_processed += 1
                continue
            
            # Download filings
            company_downloaded = 0
            
            for filing_idx, filing in enumerate(filings):
                try:
                    filing_date = filing['date']
                    
                    # Get filing details with improved error handling
                    filing_data, clean_id = get_filing_details(filing)
                    
                    if not filing_data or not clean_id:
                        logger.warning(f"Failed to get filing data/ID for {ticker or company_name} filing on {filing_date}")
                        continue
                    
                    # Create filename with clean ID
                    clean_date = filing_date.replace('-', '')
                    filename = f"{ticker or cik}_{clean_date}_{clean_id}_8K.json"
                    local_path = os.path.join(output_dir, filename)
                    
                    # Get accession number from the filing data
                    accession_number = filing_data.get("accessionNumber", "unknown")
                    
                    # Check if already downloaded
                    if os.path.exists(local_path):
                        logger.info(f"Already downloaded: {filename}")
                        writer.writerow([cik, ticker, company_name, filing_date, '8-K', accession_number, local_path, is_sp500])
                        company_downloaded += 1
                        total_downloaded += 1
                        continue
                    
                    # Save to file as JSON
                    with open(local_path, 'w', encoding='utf-8') as f:
                        json.dump(filing_data, f, indent=2)
                    
                    writer.writerow([cik, ticker, company_name, filing_date, '8-K', accession_number, local_path, is_sp500])
                    company_downloaded += 1
                    total_downloaded += 1
                    
                    logger.info(f"Downloaded {filename} ({company_downloaded}/{len(filings)})")
                    
                except Exception as e:
                    logger.error(f"Error processing filing {filing_idx+1} for {ticker or company_name}: {str(e)}")
                    import traceback
                    logger.error(traceback.format_exc())
                    continue
            
            # Mark company as processed
            save_processed_company(cik)
            companies_processed += 1
            if is_sp500:
                sp500_processed += 1
            else:
                other_processed += 1
            
            sp500_marker = "[S&P 500]" if is_sp500 else ""
            logger.info(f"Completed {ticker or company_name} {sp500_marker} - Downloaded {company_downloaded} filings")
            logger.info(f"Progress: {companies_processed}/{len(companies)} companies processed ({companies_processed/len(companies)*100:.1f}%)")
            logger.info(f"S&P 500 companies: {sp500_processed}/{len([c for c in companies if c['is_sp500']])}")
            logger.info(f"Other companies: {other_processed}/{len([c for c in companies if not c['is_sp500']])}")
            logger.info(f"Total documents downloaded: {total_downloaded}")
            
            # Calculate estimated time remaining
            if companies_processed > 0:
                elapsed_time = (datetime.now() - start_time).total_seconds()
                avg_time_per_company = elapsed_time / companies_processed
                companies_remaining = len(companies) - companies_processed
                est_time_remaining = companies_remaining * avg_time_per_company
                
                # Format as hours and minutes
                hours, remainder = divmod(est_time_remaining, 3600)
                minutes, seconds = divmod(remainder, 60)
                logger.info(f"Estimated time remaining: {int(hours)} hours, {int(minutes)} minutes")
            
            # Add longer delay between companies to avoid rate limiting
            if company_idx < len(companies) - 1:
                delay_time = random.uniform(3.0, 8.0)
                logger.info(f"Waiting {delay_time:.2f} seconds before next company...")
                time.sleep(delay_time)
        
        # Calculate total elapsed time
        end_time = datetime.now()
        elapsed_time = (end_time - start_time).total_seconds()
        hours, remainder = divmod(elapsed_time, 3600)
        minutes, seconds = divmod(remainder, 60)
        
        logger.info(f"\nCompleted processing {companies_processed} companies")
        logger.info(f"S&P 500 companies processed: {sp500_processed}")
        logger.info(f"Other companies processed: {other_processed}")
        logger.info(f"Total documents downloaded: {total_downloaded}")
        logger.info(f"Total processing time: {int(hours)} hours, {int(minutes)} minutes, {int(seconds)} seconds")
        logger.info(f"Start time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
        logger.info(f"End time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
        logger.info(f"Files saved to {output_dir}")
        logger.info(f"Metadata saved to 8k_filings.csv")

if __name__ == "__main__":
    main()
# Out:
# 2025-03-20 10:33:42,598 - INFO - Process started at 2025-03-20 10:33:42
# 2025-03-20 10:33:42,619 - INFO - Loaded 9720 companies from sec_companies2.csv
# 2025-03-20 10:33:42,619 - INFO - Downloading S&P 500 companies list...
# 2025-03-20 10:33:42,961 - ERROR - Could not find S&P 500 table in Wikipedia page
# 2025-03-20 10:33:42,962 - WARNING - Using fallback S&P 500 list (top companies only)
# 2025-03-20 10:33:42,964 - INFO - Found 96 S&P 500 companies in the input file
# 2025-03-20 10:33:42,964 - INFO - Found 9624 non-S&P 500 companies in the input file
# 2025-03-20 10:33:42,965 - INFO - Found 1272 already processed companies
# 2025-03-20 10:33:42,966 - INFO - Skipping AAPL (CIK 320193) - Already processed
# 2025-03-20 10:33:42,966 - INFO - Skipping NVDA (CIK 1045810) - Already processed
# 2025-03-20 10:33:42,966 - INFO - Skipping MSFT (CIK 789019) - Already processed
# 2025-03-20 10:33:42,967 - INFO - Skipping AMZN (CIK 1018724) - Already processed
# 2025-03-20 10:33:42,967 - INFO - Skipping GOOGL (CIK 1652044) - Already processed
# 2025-03-20 10:33:42,968 - INFO - Skipping META (CIK 1326801) - Already processed
# 2025-03-20 10:33:42,968 - INFO - Skipping AVGO (CIK 1730168) - Already processed
# 2025-03-20 10:33:42,968 - INFO - Skipping TSLA (CIK 1318605) - Already processed
# 2025-03-20 10:33:42,969 - INFO - Skipping LLY (CIK 59478) - Already processed
# 2025-03-20 10:33:42,969 - INFO - Skipping WMT (CIK 104169) - Already processed
# 2025-03-20 10:33:42,970 - INFO - Skipping V (CIK 1403161) - Already processed
# 2025-03-20 10:33:42,970 - INFO - Skipping JPM (CIK 19617) - Already processed
# 2025-03-20 10:33:42,971 - INFO - Skipping MA (CIK 1141391) - Already processed
# 2025-03-20 10:33:42,971 - INFO - Skipping XOM (CIK 34088) - Already processed
# 2025-03-20 10:33:42,971 - INFO - Skipping UNH (CIK 731766) - Already processed
# 2025-03-20 10:33:42,972 - INFO - Skipping ORCL (CIK 1341439) - Already processed
# 2025-03-20 10:33:42,972 - INFO - Skipping COST (CIK 909832) - Already processed
# 2025-03-20 10:33:42,972 - INFO - Skipping PG (CIK 80424) - Already processed
# 2025-03-20 10:33:42,973 - INFO - Skipping NFLX (CIK 1065280) - Already processed
# 2025-03-20 10:33:42,973 - INFO - Skipping ABBV (CIK 1551152) - Already processed
# 2025-03-20 10:33:42,973 - INFO - Skipping HD (CIK 354950) - Already processed
# 2025-03-20 10:33:42,974 - INFO - Skipping BAC (CIK 70858) - Already processed
# 2025-03-20 10:33:42,974 - INFO - Skipping KO (CIK 21344) - Already processed
# 2025-03-20 10:33:42,975 - INFO - Skipping CVX (CIK 93410) - Already processed
# 2025-03-20 10:33:42,975 - INFO - Skipping CRM (CIK 1108524) - Already processed
# 2025-03-20 10:33:42,975 - INFO - Skipping MRK (CIK 310158) - Already processed
# 2025-03-20 10:33:42,976 - INFO - Skipping CSCO (CIK 858877) - Already processed
# 2025-03-20 10:33:42,976 - INFO - Skipping PM (CIK 1413329) - Already processed
# 2025-03-20 10:33:42,976 - INFO - Skipping IBM (CIK 51143) - Already processed
# 2025-03-20 10:33:42,977 - INFO - Skipping WFC (CIK 72971) - Already processed
# 2025-03-20 10:33:42,977 - INFO - Skipping ABT (CIK 1800) - Already processed
# 2025-03-20 10:33:42,977 - INFO - Skipping LIN (CIK 1707925) - Already processed
# 2025-03-20 10:33:42,978 - INFO - Skipping MCD (CIK 63908) - Already processed
# 2025-03-20 10:33:42,978 - INFO - Skipping GE (CIK 40545) - Already processed
# 2025-03-20 10:33:42,979 - INFO - Skipping PEP (CIK 77476) - Already processed
# 2025-03-20 10:33:42,979 - INFO - Skipping ACN (CIK 1467373) - Already processed
# 2025-03-20 10:33:42,979 - INFO - Skipping TMO (CIK 97745) - Already processed
# 2025-03-20 10:33:42,980 - INFO - Skipping VZ (CIK 732712) - Already processed
# 2025-03-20 10:33:42,980 - INFO - Skipping MS (CIK 895421) - Already processed
# 2025-03-20 10:33:42,980 - INFO - Skipping AXP (CIK 4962) - Already processed
# 2025-03-20 10:33:42,981 - INFO - Skipping DIS (CIK 1744489) - Already processed
# 2025-03-20 10:33:42,981 - INFO - Skipping RTX (CIK 101829) - Already processed
# 2025-03-20 10:33:42,981 - INFO - Skipping ISRG (CIK 1035267) - Already processed
# 2025-03-20 10:33:42,982 - INFO - Skipping QCOM (CIK 804328) - Already processed
# 2025-03-20 10:33:42,982 - INFO - Skipping AMGN (CIK 318154) - Already processed
# 2025-03-20 10:33:42,983 - INFO - Skipping ADBE (CIK 796343) - Already processed
# 2025-03-20 10:33:42,983 - INFO - Skipping GS (CIK 886982) - Already processed
# 2025-03-20 10:33:42,983 - INFO - Skipping PGR (CIK 80661) - Already processed
# 2025-03-20 10:33:42,984 - INFO - Skipping INTU (CIK 896878) - Already processed
# 2025-03-20 10:33:42,984 - INFO - Skipping AMD (CIK 2488) - Already processed
# 2025-03-20 10:33:42,984 - INFO - Skipping CAT (CIK 18230) - Already processed
# 2025-03-20 10:33:42,985 - INFO - Skipping TXN (CIK 97476) - Already processed
# 2025-03-20 10:33:42,985 - INFO - Skipping SPGI (CIK 64040) - Already processed
# 2025-03-20 10:33:42,985 - INFO - Skipping DHR (CIK 313616) - Already processed
# 2025-03-20 10:33:42,986 - INFO - Skipping BKNG (CIK 1075531) - Already processed
# 2025-03-20 10:33:42,986 - INFO - Skipping GILD (CIK 882095) - Already processed
# 2025-03-20 10:33:42,986 - INFO - Skipping BSX (CIK 885725) - Already processed
# 2025-03-20 10:33:42,987 - INFO - Skipping BLK (CIK 2012383) - Already processed
# 2025-03-20 10:33:42,987 - INFO - Skipping SYK (CIK 310764) - Already processed
# 2025-03-20 10:33:42,987 - INFO - Skipping HON (CIK 773840) - Already processed
# 2025-03-20 10:33:42,988 - INFO - Skipping SCHW (CIK 316709) - Already processed
# 2025-03-20 10:33:42,988 - INFO - Skipping CMCSA (CIK 1166691) - Already processed
# 2025-03-20 10:33:42,989 - INFO - Skipping VRTX (CIK 875320) - Already processed
# 2025-03-20 10:33:42,989 - INFO - Skipping DE (CIK 315189) - Already processed
# 2025-03-20 10:33:42,989 - INFO - Skipping TJX (CIK 109198) - Already processed
# 2025-03-20 10:33:42,989 - INFO - Skipping C (CIK 831001) - Already processed
# 2025-03-20 10:33:42,990 - INFO - Skipping LOW (CIK 60667) - Already processed
# 2025-03-20 10:33:42,990 - INFO - Skipping COP (CIK 1163165) - Already processed
# 2025-03-20 10:33:42,990 - INFO - Skipping AMAT (CIK 6951) - Already processed
# 2025-03-20 10:33:42,991 - INFO - Skipping BA (CIK 12927) - Already processed
# 2025-03-20 10:33:42,991 - INFO - Skipping MDT (CIK 1613103) - Already processed
# 2025-03-20 10:33:42,992 - INFO - Skipping ADP (CIK 8670) - Already processed
# 2025-03-20 10:33:42,992 - INFO - Skipping CB (CIK 896159) - Already processed
# 2025-03-20 10:33:42,992 - INFO - Skipping MMC (CIK 62709) - Already processed
# 2025-03-20 10:33:42,993 - INFO - Skipping ETN (CIK 1551182) - Already processed
# 2025-03-20 10:33:42,993 - INFO - Skipping SBUX (CIK 829224) - Already processed
# 2025-03-20 10:33:42,993 - INFO - Skipping NKE (CIK 320187) - Already processed
# 2025-03-20 10:33:42,994 - INFO - Skipping PLD (CIK 1045609) - Already processed
# 2025-03-20 10:33:42,994 - INFO - Skipping INTC (CIK 50863) - Already processed
# 2025-03-20 10:33:42,994 - INFO - Skipping ADI (CIK 6281) - Already processed
# 2025-03-20 10:33:42,995 - INFO - Skipping MO (CIK 764180) - Already processed
# 2025-03-20 10:33:42,995 - INFO - Skipping UPS (CIK 1090727) - Already processed
# 2025-03-20 10:33:42,996 - INFO - Skipping SO (CIK 92122) - Already processed
# 2025-03-20 10:33:42,996 - INFO - Skipping LRCX (CIK 707549) - Already processed
# 2025-03-20 10:33:42,996 - INFO - Skipping AMT (CIK 1053507) - Already processed
# 2025-03-20 10:33:42,997 - INFO - Skipping ELV (CIK 1156039) - Already processed
# 2025-03-20 10:33:42,997 - INFO - Skipping DUK (CIK 1326160) - Already processed
# 2025-03-20 10:33:42,997 - INFO - Skipping CI (CIK 1739940) - Already processed
# 2025-03-20 10:33:42,998 - INFO - Skipping MDLZ (CIK 1103982) - Already processed
# 2025-03-20 10:33:42,998 - INFO - Skipping CVS (CIK 64803) - Already processed
# 2025-03-20 10:33:42,998 - INFO - Skipping REGN (CIK 872589) - Already processed
# 2025-03-20 10:33:42,999 - INFO - Skipping ZTS (CIK 1555280) - Already processed
# 2025-03-20 10:33:42,999 - INFO - Skipping BDX (CIK 10795) - Already processed
# 2025-03-20 10:33:42,999 - INFO - Skipping SLB (CIK 87347) - Already processed
# 2025-03-20 10:33:43,000 - INFO - Skipping TGT (CIK 27419) - Already processed
# 2025-03-20 10:33:43,000 - INFO - Skipping GOOG (CIK 1652044) - Already processed
# 2025-03-20 10:33:43,000 - INFO - Skipping BRK-B (CIK 1067983) - Already processed
# 2025-03-20 10:33:43,001 - INFO - Skipping TSM (CIK 1046179) - Already processed
# 2025-03-20 10:33:43,001 - INFO - Skipping SPY (CIK 884394) - Already processed
# 2025-03-20 10:33:43,001 - INFO - Skipping JNJ (CIK 200406) - Already processed
# 2025-03-20 10:33:43,002 - INFO - Skipping NVO (CIK 353278) - Already processed
# 2025-03-20 10:33:43,002 - INFO - Skipping BABA (CIK 1577552) - Already processed
# 2025-03-20 10:33:43,002 - INFO - Skipping SAP (CIK 1000184) - Already processed
# 2025-03-20 10:33:43,003 - INFO - Skipping TMUS (CIK 1283699) - Already processed
# 2025-03-20 10:33:43,003 - INFO - Skipping RCIT (CIK 2008670) - Already processed
# 2025-03-20 10:33:43,003 - INFO - Skipping ASML (CIK 937966) - Already processed
# 2025-03-20 10:33:43,004 - INFO - Skipping TM (CIK 1094517) - Already processed
# 2025-03-20 10:33:43,004 - INFO - Skipping AZN (CIK 901832) - Already processed
# 2025-03-20 10:33:43,004 - INFO - Skipping NVS (CIK 1114448) - Already processed
# 2025-03-20 10:33:43,005 - INFO - Skipping SHEL (CIK 1306965) - Already processed
# 2025-03-20 10:33:43,005 - INFO - Skipping HSBC (CIK 1089113) - Already processed
# 2025-03-20 10:33:43,005 - INFO - Skipping PLTR (CIK 1321655) - Already processed
# 2025-03-20 10:33:43,006 - INFO - Skipping T (CIK 732717) - Already processed
# 2025-03-20 10:33:43,006 - INFO - Skipping QQQ (CIK 1067839) - Already processed
# 2025-03-20 10:33:43,006 - INFO - Skipping FMX (CIK 1061736) - Already processed
# 2025-03-20 10:33:43,006 - INFO - Skipping NOW (CIK 1373715) - Already processed
# 2025-03-20 10:33:43,007 - INFO - Skipping BX (CIK 1393818) - Already processed
# 2025-03-20 10:33:43,007 - INFO - Skipping PDD (CIK 1737806) - Already processed
# 2025-03-20 10:33:43,007 - INFO - Skipping RY (CIK 1000275) - Already processed
# 2025-03-20 10:33:43,008 - INFO - Skipping HDB (CIK 1144967) - Already processed
# 2025-03-20 10:33:43,008 - INFO - Skipping MUFG (CIK 67088) - Already processed
# 2025-03-20 10:33:43,009 - INFO - Skipping NEE (CIK 753308) - Already processed
# 2025-03-20 10:33:43,009 - INFO - Skipping UBER (CIK 1543151) - Already processed
# 2025-03-20 10:33:43,009 - INFO - Skipping SNY (CIK 1121404) - Already processed
# 2025-03-20 10:33:43,009 - INFO - Skipping PFE (CIK 78003) - Already processed
# 2025-03-20 10:33:43,010 - INFO - Skipping UL (CIK 217410) - Already processed
# 2025-03-20 10:33:43,010 - INFO - Skipping UNP (CIK 100885) - Already processed
# 2025-03-20 10:33:43,011 - INFO - Skipping SONY (CIK 313838) - Already processed
# 2025-03-20 10:33:43,011 - INFO - Skipping EADSY (CIK 1378580) - Already processed
# 2025-03-20 10:33:43,011 - INFO - Skipping TTE (CIK 879764) - Already processed
# 2025-03-20 10:33:43,012 - INFO - Skipping BHP (CIK 811809) - Already processed
# 2025-03-20 10:33:43,013 - INFO - Skipping BMY (CIK 14272) - Already processed
# 2025-03-20 10:33:43,013 - INFO - Skipping RTNTF (CIK 887028) - Already processed
# 2025-03-20 10:33:43,013 - INFO - Skipping BUD (CIK 1668717) - Already processed
# 2025-03-20 10:33:43,014 - INFO - Skipping ARM (CIK 1973239) - Already processed
# 2025-03-20 10:33:43,014 - INFO - Skipping SHOP (CIK 1594805) - Already processed
# 2025-03-20 10:33:43,014 - INFO - Skipping FI (CIK 798354) - Already processed
# 2025-03-20 10:33:43,014 - INFO - Skipping PANW (CIK 1327567) - Already processed
# 2025-03-20 10:33:43,015 - INFO - Skipping HTHIY (CIK 47710) - Already processed
# 2025-03-20 10:33:43,015 - INFO - Skipping AIQUY (CIK 1161167) - Already processed
# 2025-03-20 10:33:43,015 - INFO - Skipping SPOT (CIK 1639920) - Already processed
# 2025-03-20 10:33:43,016 - INFO - Skipping LMT (CIK 936468) - Already processed
# 2025-03-20 10:33:43,016 - INFO - Skipping CFRUY (CIK 948401) - Already processed
# 2025-03-20 10:33:43,016 - INFO - Skipping MU (CIK 723125) - Already processed
# 2025-03-20 10:33:43,017 - INFO - Skipping IBN (CIK 1103838) - Already processed
# 2025-03-20 10:33:43,017 - INFO - Skipping ANET (CIK 1596532) - Already processed
# 2025-03-20 10:33:43,017 - INFO - Skipping MELI (CIK 1099590) - Already processed
# 2025-03-20 10:33:43,018 - INFO - Skipping TD (CIK 947263) - Already processed
# 2025-03-20 10:33:43,018 - INFO - Skipping UBS (CIK 1610520) - Already processed
# 2025-03-20 10:33:43,018 - INFO - Skipping KKR (CIK 1404912) - Already processed
# 2025-03-20 10:33:43,019 - INFO - Skipping RIO (CIK 863064) - Already processed
# 2025-03-20 10:33:43,019 - INFO - Skipping SMFG (CIK 1022837) - Already processed
# 2025-03-20 10:33:43,019 - INFO - Skipping SAN (CIK 891478) - Already processed
# 2025-03-20 10:33:43,020 - INFO - Skipping ICE (CIK 1571949) - Already processed
# 2025-03-20 10:33:43,020 - INFO - Skipping WELL (CIK 766704) - Already processed
# 2025-03-20 10:33:43,020 - INFO - Skipping CME (CIK 1156375) - Already processed
# 2025-03-20 10:33:43,021 - INFO - Skipping ENB (CIK 895728) - Already processed
# 2025-03-20 10:33:43,021 - INFO - Skipping APP (CIK 1751008) - Already processed
# 2025-03-20 10:33:43,021 - INFO - Skipping BTI (CIK 1303523) - Already processed
# 2025-03-20 10:33:43,022 - INFO - Skipping KLAC (CIK 319201) - Already processed
# 2025-03-20 10:33:43,022 - INFO - Skipping WM (CIK 823768) - Already processed
# 2025-03-20 10:33:43,023 - INFO - Skipping RELX (CIK 929869) - Already processed
# 2025-03-20 10:33:43,023 - INFO - Skipping SHW (CIK 89800) - Already processed
# 2025-03-20 10:33:43,023 - INFO - Skipping AON (CIK 315293) - Already processed
# 2025-03-20 10:33:43,024 - INFO - Skipping BP (CIK 313807) - Already processed
# 2025-03-20 10:33:43,024 - INFO - Skipping CRWD (CIK 1535527) - Already processed
# 2025-03-20 10:33:43,024 - INFO - Skipping GEV (CIK 1996810) - Already processed
# 2025-03-20 10:33:43,025 - INFO - Skipping AJG (CIK 354190) - Already processed
# 2025-03-20 10:33:43,025 - INFO - Skipping MCK (CIK 927653) - Already processed
# 2025-03-20 10:33:43,025 - INFO - Skipping EQIX (CIK 1101239) - Already processed
# 2025-03-20 10:33:43,026 - INFO - Skipping BN (CIK 1001085) - Already processed
# 2025-03-20 10:33:43,026 - INFO - Skipping GSK (CIK 1131399) - Already processed
# 2025-03-20 10:33:43,026 - INFO - Skipping BBVA (CIK 842180) - Already processed
# 2025-03-20 10:33:43,027 - INFO - Skipping MMM (CIK 66740) - Already processed
# 2025-03-20 10:33:43,027 - INFO - Skipping MCO (CIK 1059556) - Already processed
# 2025-03-20 10:33:43,027 - INFO - Skipping RACE (CIK 1648416) - Already processed
# 2025-03-20 10:33:43,028 - INFO - Skipping PBR (CIK 1119639) - Already processed
# 2025-03-20 10:33:43,028 - INFO - Skipping HCA (CIK 860730) - Already processed
# 2025-03-20 10:33:43,028 - INFO - Skipping CTAS (CIK 723254) - Already processed
# 2025-03-20 10:33:43,029 - INFO - Skipping PH (CIK 76334) - Already processed
# 2025-03-20 10:33:43,029 - INFO - Skipping TRI (CIK 1075124) - Already processed
# 2025-03-20 10:33:43,029 - INFO - Skipping INFY (CIK 1067491) - Already processed
# 2025-03-20 10:33:43,030 - INFO - Skipping TT (CIK 1466258) - Already processed
# 2025-03-20 10:33:43,030 - INFO - Skipping DASH (CIK 1792789) - Already processed
# 2025-03-20 10:33:43,030 - INFO - Skipping APH (CIK 820313) - Already processed
# 2025-03-20 10:33:43,031 - INFO - Skipping TDG (CIK 1260221) - Already processed
# 2025-03-20 10:33:43,031 - INFO - Skipping ABNB (CIK 1559720) - Already processed
# 2025-03-20 10:33:43,032 - INFO - Skipping APO (CIK 1858681) - Already processed
# 2025-03-20 10:33:43,032 - INFO - Skipping BAM (CIK 1937926) - Already processed
# 2025-03-20 10:33:43,032 - INFO - Skipping ITW (CIK 49826) - Already processed
# 2025-03-20 10:33:43,032 - INFO - Skipping ORLY (CIK 898173) - Already processed
# 2025-03-20 10:33:43,033 - INFO - Skipping CL (CIK 21665) - Already processed
# 2025-03-20 10:33:43,033 - INFO - Skipping SCCO (CIK 1001838) - Already processed
# 2025-03-20 10:33:43,034 - INFO - Skipping FTNT (CIK 1262039) - Already processed
# 2025-03-20 10:33:43,034 - INFO - Skipping SE (CIK 1703399) - Already processed
# 2025-03-20 10:33:43,034 - INFO - Skipping EPD (CIK 1061219) - Already processed
# 2025-03-20 10:33:43,035 - INFO - Skipping RSG (CIK 1060391) - Already processed
# 2025-03-20 10:33:43,035 - INFO - Skipping GLD (CIK 1222333) - Already processed
# 2025-03-20 10:33:43,035 - INFO - Skipping ECL (CIK 31462) - Already processed
# 2025-03-20 10:33:43,036 - INFO - Skipping NOC (CIK 1133421) - Already processed
# 2025-03-20 10:33:43,036 - INFO - Skipping GD (CIK 40533) - Already processed
# 2025-03-20 10:33:43,036 - INFO - Skipping MFG (CIK 1335730) - Already processed
# 2025-03-20 10:33:43,036 - INFO - Skipping MSTR (CIK 1050446) - Already processed
# 2025-03-20 10:33:43,037 - INFO - Skipping BMO (CIK 927971) - Already processed
# 2025-03-20 10:33:43,037 - INFO - Skipping MSI (CIK 68505) - Already processed
# 2025-03-20 10:33:43,037 - INFO - Skipping IBKR (CIK 1381197) - Already processed
# 2025-03-20 10:33:43,038 - INFO - Skipping CP (CIK 16875) - Already processed
# 2025-03-20 10:33:43,038 - INFO - Skipping WMB (CIK 107263) - Already processed
# 2025-03-20 10:33:43,038 - INFO - Skipping PNC (CIK 713676) - Already processed
# 2025-03-20 10:33:43,038 - INFO - Skipping NTES (CIK 1110646) - Already processed
# 2025-03-20 10:33:43,039 - INFO - Skipping EOG (CIK 821189) - Already processed
# 2025-03-20 10:33:43,039 - INFO - Skipping PYPL (CIK 1633917) - Already processed
# 2025-03-20 10:33:43,039 - INFO - Skipping SNPS (CIK 883241) - Already processed
# 2025-03-20 10:33:43,040 - INFO - Skipping CDNS (CIK 813672) - Already processed
# 2025-03-20 10:33:43,040 - INFO - Skipping CMG (CIK 1058090) - Already processed
# 2025-03-20 10:33:43,041 - INFO - Skipping TOELY (CIK 1443276) - Already processed
# 2025-03-20 10:33:43,041 - INFO - Skipping MAR (CIK 1048286) - Already processed
# 2025-03-20 10:33:43,041 - INFO - Skipping CEG (CIK 1868275) - Already processed
# 2025-03-20 10:33:43,042 - INFO - Skipping APD (CIK 2969) - Already processed
# 2025-03-20 10:33:43,042 - INFO - Skipping DELL (CIK 1571996) - Already processed
# 2025-03-20 10:33:43,042 - INFO - Skipping CRH (CIK 849395) - Already processed
# 2025-03-20 10:33:43,043 - INFO - Skipping EQNR (CIK 1140625) - Already processed
# 2025-03-20 10:33:43,043 - INFO - Skipping USB (CIK 36104) - Already processed
# 2025-03-20 10:33:43,043 - INFO - Skipping JD (CIK 1549802) - Already processed
# 2025-03-20 10:33:43,044 - INFO - Skipping COF (CIK 927628) - Already processed
# 2025-03-20 10:33:43,044 - INFO - Skipping WDAY (CIK 1327811) - Already processed
# 2025-03-20 10:33:43,045 - INFO - Skipping BAESY (CIK 895564) - Already processed
# 2025-03-20 10:33:43,045 - INFO - Skipping ET (CIK 1276187) - Already processed
# 2025-03-20 10:33:43,046 - INFO - Skipping MBGYY (CIK 1067318) - Already processed
# 2025-03-20 10:33:43,046 - INFO - Skipping EMR (CIK 32604) - Already processed
# 2025-03-20 10:33:43,046 - INFO - Skipping NGG (CIK 1004315) - Already processed
# 2025-03-20 10:33:43,047 - INFO - Skipping ROP (CIK 882835) - Already processed
# 2025-03-20 10:33:43,047 - INFO - Skipping ING (CIK 1039765) - Already processed
# 2025-03-20 10:33:43,047 - INFO - Skipping DEO (CIK 835403) - Already processed
# 2025-03-20 10:33:43,048 - INFO - Skipping CNI (CIK 16868) - Already processed
# 2025-03-20 10:33:43,048 - INFO - Skipping CNQ (CIK 1017413) - Already processed
# 2025-03-20 10:33:43,048 - INFO - Skipping MRVL (CIK 1835632) - Already processed
# 2025-03-20 10:33:43,049 - INFO - Skipping AZO (CIK 866787) - Already processed
# 2025-03-20 10:33:43,049 - INFO - Skipping SHECY (CIK 1442651) - Already processed
# 2025-03-20 10:33:43,050 - INFO - Skipping BNS (CIK 9631) - Already processed
# 2025-03-20 10:33:43,050 - INFO - Skipping KMI (CIK 1506307) - Already processed
# 2025-03-20 10:33:43,050 - INFO - Skipping FDX (CIK 1048911) - Already processed
# 2025-03-20 10:33:43,050 - INFO - Skipping OKE (CIK 1039684) - Already processed
# 2025-03-20 10:33:43,051 - INFO - Skipping TRV (CIK 86312) - Already processed
# 2025-03-20 10:33:43,051 - INFO - Skipping AFL (CIK 4977) - Already processed
# 2025-03-20 10:33:43,052 - INFO - Skipping BK (CIK 1390777) - Already processed
# 2025-03-20 10:33:43,052 - INFO - Skipping CARR (CIK 1783180) - Already processed
# 2025-03-20 10:33:43,052 - INFO - Skipping RCL (CIK 884887) - Already processed
# 2025-03-20 10:33:43,052 - INFO - Skipping BMWKY (CIK 1446250) - Already processed
# 2025-03-20 10:33:43,053 - INFO - Skipping AEP (CIK 4904) - Already processed
# 2025-03-20 10:33:43,053 - INFO - Skipping CSX (CIK 277948) - Already processed
# 2025-03-20 10:33:43,053 - INFO - Skipping TEAM (CIK 1650372) - Already processed
# 2025-03-20 10:33:43,054 - INFO - Skipping IAU (CIK 1278680) - Already processed
# 2025-03-20 10:33:43,054 - INFO - Skipping LYG (CIK 1160106) - Already processed
# 2025-03-20 10:33:43,054 - INFO - Skipping BCS (CIK 312069) - Already processed
# 2025-03-20 10:33:43,055 - INFO - Skipping FCX (CIK 831259) - Already processed
# 2025-03-20 10:33:43,055 - INFO - Skipping PTCAY (CIK 1547873) - Already processed
# 2025-03-20 10:33:43,055 - INFO - Skipping MPLX (CIK 1552000) - Already processed
# 2025-03-20 10:33:43,056 - INFO - Skipping HLT (CIK 1585689) - Already processed
# 2025-03-20 10:33:43,056 - INFO - Skipping ALL (CIK 899051) - Already processed
# 2025-03-20 10:33:43,056 - INFO - Skipping MET (CIK 1099219) - Already processed
# 2025-03-20 10:33:43,056 - INFO - Skipping MNST (CIK 865752) - Already processed
# 2025-03-20 10:33:43,057 - INFO - Skipping CAIXY (CIK 1535628) - Already processed
# 2025-03-20 10:33:43,057 - INFO - Skipping ADSK (CIK 769397) - Already processed
# 2025-03-20 10:33:43,058 - INFO - Skipping ITUB (CIK 1132597) - Already processed
# 2025-03-20 10:33:43,058 - INFO - Skipping NU (CIK 1691493) - Already processed
# 2025-03-20 10:33:43,058 - INFO - Skipping PCAR (CIK 75362) - Already processed
# 2025-03-20 10:33:43,059 - INFO - Skipping CM (CIK 1045520) - Already processed
# 2025-03-20 10:33:43,059 - INFO - Skipping PAYX (CIK 723531) - Already processed
# 2025-03-20 10:33:43,059 - INFO - Skipping PSA (CIK 1393311) - Already processed
# 2025-03-20 10:33:43,060 - INFO - Skipping TFC (CIK 92230) - Already processed
# 2025-03-20 10:33:43,060 - INFO - Skipping NSC (CIK 702165) - Already processed
# 2025-03-20 10:33:43,060 - INFO - Skipping AEM (CIK 2809) - Already processed
# 2025-03-20 10:33:43,061 - INFO - Skipping NEM (CIK 1164727) - Already processed
# 2025-03-20 10:33:43,061 - INFO - Skipping NXPI (CIK 1413447) - Already processed
# 2025-03-20 10:33:43,061 - INFO - Skipping JCI (CIK 833444) - Already processed
# 2025-03-20 10:33:43,062 - INFO - Skipping CPRT (CIK 900075) - Already processed
# 2025-03-20 10:33:43,062 - INFO - Skipping DLR (CIK 1297996) - Already processed
# 2025-03-20 10:33:43,062 - INFO - Skipping O (CIK 726728) - Already processed
# 2025-03-20 10:33:43,063 - INFO - Skipping PSX (CIK 1534701) - Already processed
# 2025-03-20 10:33:43,063 - INFO - Skipping HWM (CIK 4281) - Already processed
# 2025-03-20 10:33:43,064 - INFO - Skipping SNOW (CIK 1640147) - Already processed
# 2025-03-20 10:33:43,064 - INFO - Skipping COR (CIK 1140859) - Already processed
# 2025-03-20 10:33:43,064 - INFO - Skipping CHTR (CIK 1091667) - Already processed
# 2025-03-20 10:33:43,064 - INFO - Skipping MFC (CIK 1086888) - Already processed
# 2025-03-20 10:33:43,065 - INFO - Skipping GLNCY (CIK 1524684) - Already processed
# 2025-03-20 10:33:43,065 - INFO - Skipping AIG (CIK 5272) - Already processed
# 2025-03-20 10:33:43,066 - INFO - Skipping TRP (CIK 1232384) - Already processed
# 2025-03-20 10:33:43,066 - INFO - Skipping TAK (CIK 1395064) - Already processed
# 2025-03-20 10:33:43,066 - INFO - Skipping AMP (CIK 820027) - Already processed
# 2025-03-20 10:33:43,067 - INFO - Skipping NWG (CIK 844150) - Already processed
# 2025-03-20 10:33:43,067 - INFO - Skipping WCN (CIK 1318220) - Already processed
# 2025-03-20 10:33:43,067 - INFO - Skipping GM (CIK 1467858) - Already processed
# 2025-03-20 10:33:43,068 - INFO - Skipping LNG (CIK 3570) - Already processed
# 2025-03-20 10:33:43,068 - INFO - Skipping KMB (CIK 55785) - Already processed
# 2025-03-20 10:33:43,068 - INFO - Skipping HLN (CIK 1900304) - Already processed
# 2025-03-20 10:33:43,068 - INFO - Skipping GWW (CIK 277135) - Already processed
# 2025-03-20 10:33:43,069 - INFO - Skipping D (CIK 715957) - Already processed
# 2025-03-20 10:33:43,069 - INFO - Skipping COIN (CIK 1679788) - Already processed
# 2025-03-20 10:33:43,069 - INFO - Skipping E (CIK 1002242) - Already processed
# 2025-03-20 10:33:43,070 - INFO - Skipping DB (CIK 1159508) - Already processed
# 2025-03-20 10:33:43,070 - INFO - Skipping KDP (CIK 1418135) - Already processed
# 2025-03-20 10:33:43,071 - INFO - Skipping KVUE (CIK 1944048) - Already processed
# 2025-03-20 10:33:43,071 - INFO - Skipping HES (CIK 4447) - Already processed
# 2025-03-20 10:33:43,071 - INFO - Skipping ARES (CIK 1176948) - Already processed
# 2025-03-20 10:33:43,072 - INFO - Skipping GBTC (CIK 1588489) - Already processed
# 2025-03-20 10:33:43,072 - INFO - Skipping SRE (CIK 1032208) - Already processed
# 2025-03-20 10:33:43,072 - INFO - Skipping SU (CIK 311337) - Already processed
# 2025-03-20 10:33:43,073 - INFO - Skipping AMX (CIK 1129137) - Already processed
# 2025-03-20 10:33:43,073 - INFO - Skipping KR (CIK 56873) - Already processed
# 2025-03-20 10:33:43,073 - INFO - Skipping EXC (CIK 1109357) - Already processed
# 2025-03-20 10:33:43,074 - INFO - Skipping CMI (CIK 26172) - Already processed
# 2025-03-20 10:33:43,074 - INFO - Skipping ALC (CIK 1167379) - Already processed
# 2025-03-20 10:33:43,075 - INFO - Skipping FICO (CIK 814547) - Already processed
# 2025-03-20 10:33:43,075 - INFO - Skipping HMC (CIK 715153) - Already processed
# 2025-03-20 10:33:43,075 - INFO - Skipping YUM (CIK 1041061) - Already processed
# 2025-03-20 10:33:43,076 - INFO - Skipping FAST (CIK 815556) - Already processed
# 2025-03-20 10:33:43,076 - INFO - Skipping MPC (CIK 1510295) - Already processed
# 2025-03-20 10:33:43,077 - INFO - Skipping OXY (CIK 797468) - Already processed
# 2025-03-20 10:33:43,077 - INFO - Skipping TEL (CIK 1385157) - Already processed
# 2025-03-20 10:33:43,077 - INFO - Skipping MSCI (CIK 1408198) - Already processed
# 2025-03-20 10:33:43,078 - INFO - Skipping FANG (CIK 1539838) - Already processed
# 2025-03-20 10:33:43,078 - INFO - Skipping NDAQ (CIK 1120193) - Already processed
# 2025-03-20 10:33:43,078 - INFO - Skipping BKR (CIK 1701605) - Already processed
# 2025-03-20 10:33:43,079 - INFO - Skipping FLUT (CIK 1635327) - Already processed
# 2025-03-20 10:33:43,079 - INFO - Skipping CCI (CIK 1051470) - Already processed
# 2025-03-20 10:33:43,079 - INFO - Skipping AXON (CIK 1069183) - Already processed
# 2025-03-20 10:33:43,080 - INFO - Skipping ROST (CIK 745732) - Already processed
# 2025-03-20 10:33:43,080 - INFO - Skipping VRSK (CIK 1442145) - Already processed
# 2025-03-20 10:33:43,080 - INFO - Skipping GRMN (CIK 1121788) - Already processed
# 2025-03-20 10:33:43,081 - INFO - Skipping VALE (CIK 917851) - Already processed
# 2025-03-20 10:33:43,081 - INFO - Skipping DHI (CIK 882184) - Already processed
# 2025-03-20 10:33:43,081 - INFO - Skipping AME (CIK 1037868) - Already processed
# 2025-03-20 10:33:43,082 - INFO - Skipping DFS (CIK 1393612) - Already processed
# 2025-03-20 10:33:43,082 - INFO - Skipping CPNG (CIK 1834584) - Already processed
# 2025-03-20 10:33:43,082 - INFO - Skipping CTVA (CIK 1755672) - Already processed
# 2025-03-20 10:33:43,082 - INFO - Skipping EW (CIK 1099800) - Already processed
# 2025-03-20 10:33:43,083 - INFO - Skipping VST (CIK 1692819) - Already processed
# 2025-03-20 10:33:43,083 - INFO - Skipping TRGP (CIK 1389170) - Already processed
# 2025-03-20 10:33:43,083 - INFO - Skipping NET (CIK 1477333) - Already processed
# 2025-03-20 10:33:43,084 - INFO - Skipping LHX (CIK 202058) - Already processed
# 2025-03-20 10:33:43,084 - INFO - Skipping OTIS (CIK 1781335) - Already processed
# 2025-03-20 10:33:43,084 - INFO - Skipping TCOM (CIK 1269238) - Already processed
# 2025-03-20 10:33:43,085 - INFO - Skipping PEG (CIK 788784) - Already processed
# 2025-03-20 10:33:43,085 - INFO - Skipping VLO (CIK 1035002) - Already processed
# 2025-03-20 10:33:43,085 - INFO - Skipping XEL (CIK 72903) - Already processed
# 2025-03-20 10:33:43,086 - INFO - Skipping GLW (CIK 24741) - Already processed
# 2025-03-20 10:33:43,086 - INFO - Skipping CTSH (CIK 1058290) - Already processed
# 2025-03-20 10:33:43,086 - INFO - Skipping ATEYY (CIK 1158838) - Already processed
# 2025-03-20 10:33:43,086 - INFO - Skipping URI (CIK 1067701) - Already processed
# 2025-03-20 10:33:43,087 - INFO - Skipping SVNDY (CIK 1359519) - Already processed
# 2025-03-20 10:33:43,087 - INFO - Skipping CCEP (CIK 1650107) - Already processed
# 2025-03-20 10:33:43,088 - INFO - Skipping F (CIK 37996) - Already processed
# 2025-03-20 10:33:43,088 - INFO - Skipping LULU (CIK 1397187) - Already processed
# 2025-03-20 10:33:43,088 - INFO - Skipping DNZOY (CIK 1446598) - Already processed
# 2025-03-20 10:33:43,088 - INFO - Skipping GEHC (CIK 1932393) - Already processed
# 2025-03-20 10:33:43,089 - INFO - Skipping FIS (CIK 1136893) - Already processed
# 2025-03-20 10:33:43,089 - INFO - Skipping PRU (CIK 1137774) - Already processed
# 2025-03-20 10:33:43,089 - INFO - Skipping VEEV (CIK 1393052) - Already processed
# 2025-03-20 10:33:43,090 - INFO - Skipping PWR (CIK 1050915) - Already processed
# 2025-03-20 10:33:43,090 - INFO - Skipping RBLX (CIK 1315098) - Already processed
# 2025-03-20 10:33:43,090 - INFO - Skipping ED (CIK 1047862) - Already processed
# 2025-03-20 10:33:43,090 - INFO - Skipping CBRE (CIK 1138118) - Already processed
# 2025-03-20 10:33:43,091 - INFO - Skipping KHC (CIK 1637459) - Already processed
# 2025-03-20 10:33:43,091 - INFO - Skipping EA (CIK 712515) - Already processed
# 2025-03-20 10:33:43,091 - INFO - Skipping TTWO (CIK 946581) - Already processed
# 2025-03-20 10:33:43,092 - INFO - Skipping PCG (CIK 1004980) - Already processed
# 2025-03-20 10:33:43,092 - INFO - Skipping WTKWY (CIK 861967) - Already processed
# 2025-03-20 10:33:43,092 - INFO - Skipping SYY (CIK 96021) - Already processed
# 2025-03-20 10:33:43,093 - INFO - Skipping ETR (CIK 65984) - Already processed
# 2025-03-20 10:33:43,093 - INFO - Skipping ARGX (CIK 1697862) - Already processed
# 2025-03-20 10:33:43,093 - INFO - Skipping ABEV (CIK 1565025) - Already processed
# 2025-03-20 10:33:43,094 - INFO - Skipping IT (CIK 749251) - Already processed
# 2025-03-20 10:33:43,094 - INFO - Skipping HSY (CIK 47111) - Already processed
# 2025-03-20 10:33:43,094 - INFO - Skipping ANYYY (CIK 1700171) - Already processed
# 2025-03-20 10:33:43,095 - INFO - Skipping OLCLY (CIK 1545460) - Already processed
# 2025-03-20 10:33:43,095 - INFO - Skipping ODFL (CIK 878927) - Already processed
# 2025-03-20 10:33:43,095 - INFO - Skipping STLA (CIK 1605484) - Already processed
# 2025-03-20 10:33:43,096 - INFO - Skipping DDOG (CIK 1561550) - Already processed
# 2025-03-20 10:33:43,096 - INFO - Skipping IMO (CIK 49938) - Already processed
# 2025-03-20 10:33:43,096 - INFO - Skipping ACGL (CIK 947484) - Already processed
# 2025-03-20 10:33:43,097 - INFO - Skipping BRO (CIK 79282) - Already processed
# 2025-03-20 10:33:43,097 - INFO - Skipping XYZ (CIK 1512673) - Already processed
# 2025-03-20 10:33:43,097 - INFO - Skipping A (CIK 1090872) - Already processed
# 2025-03-20 10:33:43,098 - INFO - Skipping VICI (CIK 1705696) - Already processed
# 2025-03-20 10:33:43,098 - INFO - Skipping HIG (CIK 874766) - Already processed
# 2025-03-20 10:33:43,098 - INFO - Skipping DIA (CIK 1041130) - Already processed
# 2025-03-20 10:33:43,099 - INFO - Skipping BIDU (CIK 1329099) - Already processed
# 2025-03-20 10:33:43,099 - INFO - Skipping DKILY (CIK 1446519) - Already processed
# 2025-03-20 10:33:43,099 - INFO - Skipping WEC (CIK 783325) - Already processed
# 2025-03-20 10:33:43,099 - INFO - Skipping IDXX (CIK 874716) - Already processed
# 2025-03-20 10:33:43,100 - INFO - Skipping WPM (CIK 1323404) - Already processed
# 2025-03-20 10:33:43,100 - INFO - Skipping BSBR (CIK 1471055) - Already processed
# 2025-03-20 10:33:43,100 - INFO - Skipping GIS (CIK 40704) - Already processed
# 2025-03-20 10:33:43,101 - INFO - Skipping GWLIF (CIK 850918) - Already processed
# 2025-03-20 10:33:43,101 - INFO - Skipping STZ (CIK 16918) - Already processed
# 2025-03-20 10:33:43,101 - INFO - Skipping GOLD (CIK 756894) - Already processed
# 2025-03-20 10:33:43,102 - INFO - Skipping IR (CIK 1699150) - Already processed
# 2025-03-20 10:33:43,102 - INFO - Skipping HOOD (CIK 1783879) - Already processed
# 2025-03-20 10:33:43,102 - INFO - Skipping RMD (CIK 943819) - Already processed
# 2025-03-20 10:33:43,102 - INFO - Skipping IQV (CIK 1478242) - Already processed
# 2025-03-20 10:33:43,102 - INFO - Skipping EXR (CIK 1289490) - Already processed
# 2025-03-20 10:33:43,103 - INFO - Skipping WIT (CIK 1123799) - Already processed
# 2025-03-20 10:33:43,103 - INFO - Skipping CSGP (CIK 1057352) - Already processed
# 2025-03-20 10:33:43,103 - INFO - Skipping WTW (CIK 1140536) - Already processed
# 2025-03-20 10:33:43,104 - INFO - Skipping VRT (CIK 1674101) - Already processed
# 2025-03-20 10:33:43,104 - INFO - Skipping PPRUY (CIK 1445465) - Already processed
# 2025-03-20 10:33:43,104 - INFO - Skipping MRAAY (CIK 1450468) - Already processed
# 2025-03-20 10:33:43,105 - INFO - Skipping ALNY (CIK 1178670) - Already processed
# 2025-03-20 10:33:43,105 - INFO - Skipping DD (CIK 1666700) - Already processed
# 2025-03-20 10:33:43,105 - INFO - Skipping HUBS (CIK 1404655) - Already processed
# 2025-03-20 10:33:43,106 - INFO - Skipping FERG (CIK 2011641) - Already processed
# 2025-03-20 10:33:43,106 - INFO - Skipping FER (CIK 1468522) - Already processed
# 2025-03-20 10:33:43,106 - INFO - Skipping SLF (CIK 1097362) - Already processed
# 2025-03-20 10:33:43,107 - INFO - Skipping LVS (CIK 1300514) - Already processed
# 2025-03-20 10:33:43,107 - INFO - Skipping LEN (CIK 920760) - Already processed
# 2025-03-20 10:33:43,107 - INFO - Skipping CQP (CIK 1383650) - Already processed
# 2025-03-20 10:33:43,107 - INFO - Skipping CAH (CIK 721371) - Already processed
# 2025-03-20 10:33:43,108 - INFO - Skipping CHT (CIK 1132924) - Already processed
# 2025-03-20 10:33:43,108 - INFO - Skipping HEI (CIK 46619) - Already processed
# 2025-03-20 10:33:43,108 - INFO - Skipping HUM (CIK 49071) - Already processed
# 2025-03-20 10:33:43,109 - INFO - Skipping EBAY (CIK 1065088) - Already processed
# 2025-03-20 10:33:43,109 - INFO - Skipping WAB (CIK 943452) - Already processed
# 2025-03-20 10:33:43,109 - INFO - Skipping NUE (CIK 73309) - Already processed
# 2025-03-20 10:33:43,110 - INFO - Skipping QSR (CIK 1618756) - Already processed
# 2025-03-20 10:33:43,110 - INFO - Skipping FRFHF (CIK 915191) - Already processed
# 2025-03-20 10:33:43,110 - INFO - Skipping VMC (CIK 1396009) - Already processed
# 2025-03-20 10:33:43,111 - INFO - Skipping AVB (CIK 915912) - Already processed
# 2025-03-20 10:33:43,111 - INFO - Skipping LI (CIK 1791706) - Already processed
# 2025-03-20 10:33:43,112 - INFO - Skipping ZS (CIK 1713683) - Already processed
# 2025-03-20 10:33:43,112 - INFO - Skipping XYL (CIK 1524472) - Already processed
# 2025-03-20 10:33:43,112 - INFO - Skipping EFX (CIK 33185) - Already processed
# 2025-03-20 10:33:43,113 - INFO - Skipping TW (CIK 1758730) - Already processed
# 2025-03-20 10:33:43,113 - INFO - Skipping MDY (CIK 936958) - Already processed
# 2025-03-20 10:33:43,113 - INFO - Skipping EQT (CIK 33213) - Already processed
# 2025-03-20 10:33:43,114 - INFO - Skipping TPL (CIK 1811074) - Already processed
# 2025-03-20 10:33:43,114 - INFO - Skipping ROK (CIK 1024478) - Already processed
# 2025-03-20 10:33:43,114 - INFO - Skipping VTR (CIK 740260) - Already processed
# 2025-03-20 10:33:43,115 - INFO - Skipping FNV (CIK 1456346) - Already processed
# 2025-03-20 10:33:43,115 - INFO - Skipping RJF (CIK 720005) - Already processed
# 2025-03-20 10:33:43,115 - INFO - Skipping RKT (CIK 1805284) - Already processed
# 2025-03-20 10:33:43,115 - INFO - Skipping DAL (CIK 27904) - Already processed
# 2025-03-20 10:33:43,116 - INFO - Skipping CNC (CIK 1071739) - Already processed
# 2025-03-20 10:33:43,116 - INFO - Skipping NOK (CIK 924613) - Already processed
# 2025-03-20 10:33:43,116 - INFO - Skipping K (CIK 55067) - Already processed
# 2025-03-20 10:33:43,117 - INFO - Skipping MLM (CIK 916076) - Already processed
# 2025-03-20 10:33:43,117 - INFO - Skipping OWL (CIK 1823945) - Already processed
# 2025-03-20 10:33:43,117 - INFO - Skipping MTB (CIK 36270) - Already processed
# 2025-03-20 10:33:43,118 - INFO - Skipping ONC (CIK 1651308) - Already processed
# 2025-03-20 10:33:43,118 - INFO - Skipping MCHP (CIK 827054) - Already processed
# 2025-03-20 10:33:43,118 - INFO - Skipping ANSS (CIK 1013462) - Already processed
# 2025-03-20 10:33:43,119 - INFO - Skipping NVZMY (CIK 1131345) - Already processed
# 2025-03-20 10:33:43,119 - INFO - Skipping MPWR (CIK 1280452) - Already processed
# 2025-03-20 10:33:43,119 - INFO - Skipping AWK (CIK 1410636) - Already processed
# 2025-03-20 10:33:43,119 - INFO - Skipping TSCO (CIK 916365) - Already processed
# 2025-03-20 10:33:43,120 - INFO - Skipping BEKE (CIK 1809587) - Already processed
# 2025-03-20 10:33:43,120 - INFO - Skipping DTE (CIK 936340) - Already processed
# 2025-03-20 10:33:43,120 - INFO - Skipping PPERY (CIK 1461748) - Already processed
# 2025-03-20 10:33:43,121 - INFO - Skipping TTD (CIK 1671933) - Already processed
# 2025-03-20 10:33:43,121 - INFO - Skipping CHD (CIK 313927) - Already processed
# 2025-03-20 10:33:43,121 - INFO - Skipping DXCM (CIK 1093557) - Already processed
# 2025-03-20 10:33:43,122 - INFO - Skipping WDS (CIK 844551) - Already processed
# 2025-03-20 10:33:43,122 - INFO - Skipping EQR (CIK 906107) - Already processed
# 2025-03-20 10:33:43,122 - INFO - Skipping FANUY (CIK 1446596) - Already processed
# 2025-03-20 10:33:43,123 - INFO - Skipping ERIC (CIK 717826) - Already processed
# 2025-03-20 10:33:43,123 - INFO - Skipping LYV (CIK 1335258) - Already processed
# 2025-03-20 10:33:43,123 - INFO - Skipping IP (CIK 51434) - Already processed
# 2025-03-20 10:33:43,123 - INFO - Skipping TEF (CIK 814052) - Already processed
# 2025-03-20 10:33:43,124 - INFO - Skipping AEE (CIK 1002910) - Already processed
# 2025-03-20 10:33:43,124 - INFO - Skipping BR (CIK 1383312) - Already processed
# 2025-03-20 10:33:43,124 - INFO - Skipping HPQ (CIK 47217) - Already processed
# 2025-03-20 10:33:43,125 - INFO - Skipping NTDTY (CIK 1446705) - Already processed
# 2025-03-20 10:33:43,125 - INFO - Skipping KEYS (CIK 1601046) - Already processed
# 2025-03-20 10:33:43,125 - INFO - Skipping CCL (CIK 815097) - Already processed
# 2025-03-20 10:33:43,126 - INFO - Skipping DIDIY (CIK 1764757) - Already processed
# 2025-03-20 10:33:43,126 - INFO - Skipping SAXPY (CIK 1436778) - Already processed
# 2025-03-20 10:33:43,126 - INFO - Skipping DOW (CIK 1751788) - Already processed
# 2025-03-20 10:33:43,127 - INFO - Skipping YAHOY (CIK 1446437) - Already processed
# 2025-03-20 10:33:43,127 - INFO - Skipping PPG (CIK 79879) - Already processed
# 2025-03-20 10:33:43,128 - INFO - Skipping MTD (CIK 1037646) - Already processed
# 2025-03-20 10:33:43,128 - INFO - Skipping PPL (CIK 922224) - Already processed
# 2025-03-20 10:33:43,128 - INFO - Skipping DSCSY (CIK 1671750) - Already processed
# 2025-03-20 10:33:43,129 - INFO - Skipping PUK (CIK 1116578) - Already processed
# 2025-03-20 10:33:43,129 - INFO - Skipping IRM (CIK 1020569) - Already processed
# 2025-03-20 10:33:43,129 - INFO - Skipping RYAAY (CIK 1038683) - Already processed
# 2025-03-20 10:33:43,130 - INFO - Skipping WBD (CIK 1437107) - Already processed
# 2025-03-20 10:33:43,130 - INFO - Skipping PUBGY (CIK 1050952) - Already processed
# 2025-03-20 10:33:43,130 - INFO - Skipping FTV (CIK 1659166) - Already processed
# 2025-03-20 10:33:43,130 - INFO - Skipping GDDY (CIK 1609711) - Already processed
# 2025-03-20 10:33:43,131 - INFO - Skipping NTR (CIK 1725964) - Already processed
# 2025-03-20 10:33:43,131 - INFO - Skipping ROL (CIK 84839) - Already processed
# 2025-03-20 10:33:43,131 - INFO - Skipping STT (CIK 93751) - Already processed
# 2025-03-20 10:33:43,132 - INFO - Skipping MT (CIK 1243429) - Already processed
# 2025-03-20 10:33:43,132 - INFO - Skipping DOV (CIK 29905) - Already processed
# 2025-03-20 10:33:43,132 - INFO - Skipping PHG (CIK 313216) - Already processed
# 2025-03-20 10:33:43,133 - INFO - Skipping FUJIY (CIK 800365) - Already processed
# 2025-03-20 10:33:43,133 - INFO - Skipping XPEV (CIK 1810997) - Already processed
# 2025-03-20 10:33:43,133 - INFO - Skipping TYL (CIK 860731) - Already processed
# 2025-03-20 10:33:43,133 - INFO - Skipping BNTX (CIK 1776985) - Already processed
# 2025-03-20 10:33:43,134 - INFO - Skipping IX (CIK 1070304) - Already processed
# 2025-03-20 10:33:43,134 - INFO - Skipping CHKP (CIK 1015922) - Already processed
# 2025-03-20 10:33:43,134 - INFO - Skipping VOD (CIK 839923) - Already processed
# 2025-03-20 10:33:43,135 - INFO - Skipping CVE (CIK 1475260) - Already processed
# 2025-03-20 10:33:43,135 - INFO - Skipping VG (CIK 2007855) - Already processed
# 2025-03-20 10:33:43,135 - INFO - Skipping SMCI (CIK 1375365) - Already processed
# 2025-03-20 10:33:43,136 - INFO - Skipping VLTO (CIK 1967680) - Already processed
# 2025-03-20 10:33:43,136 - INFO - Skipping EXE (CIK 895126) - Already processed
# 2025-03-20 10:33:43,136 - INFO - Skipping EJPRY (CIK 1093028) - Already processed
# 2025-03-20 10:33:43,137 - INFO - Skipping EL (CIK 1001250) - Already processed
# 2025-03-20 10:33:43,137 - INFO - Skipping LYB (CIK 1489393) - Already processed
# 2025-03-20 10:33:43,138 - INFO - Skipping WRB (CIK 11544) - Already processed
# 2025-03-20 10:33:43,138 - INFO - Skipping MKL (CIK 1096343) - Already processed
# 2025-03-20 10:33:43,138 - INFO - Skipping ATO (CIK 731802) - Already processed
# 2025-03-20 10:33:43,139 - INFO - Skipping FCNCA (CIK 798941) - Already processed
# 2025-03-20 10:33:43,139 - INFO - Skipping CPAY (CIK 1175454) - Already processed
# 2025-03-20 10:33:43,139 - INFO - Skipping LPLA (CIK 1397911) - Already processed
# 2025-03-20 10:33:43,139 - INFO - Skipping SBAC (CIK 1034054) - Already processed
# 2025-03-20 10:33:43,140 - INFO - Skipping GPN (CIK 1123360) - Already processed
# 2025-03-20 10:33:43,140 - INFO - Skipping UAL (CIK 100517) - Already processed
# 2025-03-20 10:33:43,140 - INFO - Skipping TU (CIK 868675) - Already processed
# 2025-03-20 10:33:43,140 - INFO - Skipping SW (CIK 2005951) - Already processed
# 2025-03-20 10:33:43,141 - INFO - Skipping GIB (CIK 1061574) - Already processed
# 2025-03-20 10:33:43,141 - INFO - Skipping CBOE (CIK 1374310) - Already processed
# 2025-03-20 10:33:43,142 - INFO - Skipping CNP (CIK 1130310) - Already processed
# 2025-03-20 10:33:43,142 - INFO - Skipping ADM (CIK 7084) - Already processed
# 2025-03-20 10:33:43,142 - INFO - Skipping FE (CIK 1031296) - Already processed
# 2025-03-20 10:33:43,142 - INFO - Skipping TDY (CIK 1094285) - Already processed
# 2025-03-20 10:33:43,143 - INFO - Skipping BCE (CIK 718940) - Already processed
# 2025-03-20 10:33:43,143 - INFO - Skipping FOXA (CIK 1754301) - Already processed
# 2025-03-20 10:33:43,143 - INFO - Skipping PBA (CIK 1546066) - Already processed
# 2025-03-20 10:33:43,143 - INFO - Skipping FTS (CIK 1666175) - Already processed
# 2025-03-20 10:33:43,144 - INFO - Skipping CINF (CIK 20286) - Already processed
# 2025-03-20 10:33:43,144 - INFO - Skipping CUK (CIK 1125259) - Already processed
# 2025-03-20 10:33:43,145 - INFO - Skipping VRSN (CIK 1014473) - Already processed
# 2025-03-20 10:33:43,145 - INFO - Skipping RDDT (CIK 1713445) - Already processed
# 2025-03-20 10:33:43,146 - INFO - Skipping ZM (CIK 1585521) - Already processed
# 2025-03-20 10:33:43,146 - INFO - Skipping ES (CIK 72741) - Already processed
# 2025-03-20 10:33:43,146 - INFO - Skipping ERIE (CIK 922621) - Already processed
# 2025-03-20 10:33:43,147 - INFO - Skipping STE (CIK 1757898) - Already processed
# 2025-03-20 10:33:43,147 - INFO - Skipping DVN (CIK 1090012) - Already processed
# 2025-03-20 10:33:43,147 - INFO - Skipping CDW (CIK 1402057) - Already processed
# 2025-03-20 10:33:43,147 - INFO - Skipping WAT (CIK 1000697) - Already processed
# 2025-03-20 10:33:43,148 - INFO - Skipping MKC (CIK 63754) - Already processed
# 2025-03-20 10:33:43,148 - INFO - Skipping STM (CIK 932787) - Already processed
# 2025-03-20 10:33:43,148 - INFO - Skipping EIX (CIK 827052) - Already processed
# 2025-03-20 10:33:43,148 - INFO - Skipping CMS (CIK 811156) - Already processed
# 2025-03-20 10:33:43,149 - INFO - Skipping TSN (CIK 100493) - Already processed
# 2025-03-20 10:33:43,149 - INFO - Skipping PINS (CIK 1506293) - Already processed
# 2025-03-20 10:33:43,149 - INFO - Skipping DRI (CIK 940944) - Already processed
# 2025-03-20 10:33:43,149 - INFO - Skipping ZBH (CIK 1136869) - Already processed
# 2025-03-20 10:33:43,150 - INFO - Skipping HAL (CIK 45012) - Already processed
# 2025-03-20 10:33:43,150 - INFO - Skipping WY (CIK 106535) - Already processed
# 2025-03-20 10:33:43,151 - INFO - Skipping IOT (CIK 1642896) - Already processed
# 2025-03-20 10:33:43,151 - INFO - Skipping ASX (CIK 1122411) - Already processed
# 2025-03-20 10:33:43,151 - INFO - Skipping NJDCY (CIK 1158967) - Already processed
# 2025-03-20 10:33:43,151 - INFO - Skipping TME (CIK 1744676) - Already processed
# 2025-03-20 10:33:43,152 - INFO - Skipping NVR (CIK 906163) - Already processed
# 2025-03-20 10:33:43,152 - INFO - Skipping PHM (CIK 822416) - Already processed
# 2025-03-20 10:33:43,152 - INFO - Skipping TROW (CIK 1113169) - Already processed
# 2025-03-20 10:33:43,153 - INFO - Skipping BIIB (CIK 875045) - Already processed
# 2025-03-20 10:33:43,153 - INFO - Skipping EXPE (CIK 1324424) - Already processed
# 2025-03-20 10:33:43,153 - INFO - Skipping CJPRY (CIK 1334687) - Already processed
# 2025-03-20 10:33:43,154 - INFO - Skipping CTRA (CIK 858470) - Already processed
# 2025-03-20 10:33:43,154 - INFO - Skipping WSM (CIK 719955) - Already processed
# 2025-03-20 10:33:43,155 - INFO - Skipping IFF (CIK 51253) - Already processed
# 2025-03-20 10:33:43,155 - INFO - Skipping BBD (CIK 1160330) - Already processed
# 2025-03-20 10:33:43,155 - INFO - Skipping TECK (CIK 886986) - Already processed
# 2025-03-20 10:33:43,155 - INFO - Skipping SYF (CIK 1601712) - Already processed
# 2025-03-20 10:33:43,156 - INFO - Skipping GFS (CIK 1709048) - Already processed
# 2025-03-20 10:33:43,156 - INFO - Skipping INVH (CIK 1687229) - Already processed
# 2025-03-20 10:33:43,156 - INFO - Skipping KB (CIK 1445930) - Already processed
# 2025-03-20 10:33:43,157 - INFO - Skipping EC (CIK 1444406) - Already processed
# 2025-03-20 10:33:43,157 - INFO - Skipping LII (CIK 1069202) - Already processed
# 2025-03-20 10:33:43,157 - INFO - Skipping ESS (CIK 920522) - Already processed
# 2025-03-20 10:33:43,158 - INFO - Skipping WSO (CIK 105016) - Already processed
# 2025-03-20 10:33:43,158 - INFO - Skipping TS (CIK 1190723) - Already processed
# 2025-03-20 10:33:43,158 - INFO - Skipping SSNC (CIK 1402436) - Already processed
# 2025-03-20 10:33:43,159 - INFO - Skipping LH (CIK 920148) - Already processed
# 2025-03-20 10:33:43,159 - INFO - Skipping CVNA (CIK 1690820) - Already processed
# 2025-03-20 10:33:43,159 - INFO - Skipping HPE (CIK 1645590) - Already processed
# 2025-03-20 10:33:43,160 - INFO - Skipping KSPI (CIK 1985487) - Already processed
# 2025-03-20 10:33:43,160 - INFO - Skipping MAA (CIK 912595) - Already processed
# 2025-03-20 10:33:43,160 - INFO - Skipping PHYS (CIK 1477049) - Already processed
# 2025-03-20 10:33:43,160 - INFO - Skipping NTRA (CIK 1604821) - Already processed
# 2025-03-20 10:33:43,161 - INFO - Skipping RF (CIK 1281761) - Already processed
# 2025-03-20 10:33:43,161 - INFO - Skipping TEVA (CIK 818686) - Already processed
# 2025-03-20 10:33:43,161 - INFO - Skipping RPRX (CIK 1802768) - Already processed
# 2025-03-20 10:33:43,162 - INFO - Skipping SGSOY (CIK 1069347) - Already processed
# 2025-03-20 10:33:43,162 - INFO - Skipping TELNY (CIK 1126113) - Already processed
# 2025-03-20 10:33:43,162 - INFO - Skipping NTRS (CIK 73124) - Already processed
# 2025-03-20 10:33:43,163 - INFO - Skipping DGX (CIK 1022079) - Already processed
# 2025-03-20 10:33:43,163 - INFO - Skipping TOST (CIK 1650164) - Already processed
# 2025-03-20 10:33:43,163 - INFO - Skipping OKTA (CIK 1660134) - Already processed
# 2025-03-20 10:33:43,164 - INFO - Skipping GFI (CIK 1172724) - Already processed
# ...
# 2025-03-20 11:00:16,509 - INFO - Downloaded LEA_20240520_000084216224000037_8K.json (4/7)
# 2025-03-20 11:00:16,510 - INFO - Processing filing data for 2024-04-30 - LEA
# 2025-03-20 11:00:16,510 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/842162/000084216224000030/0000842162-24-000030-index.htm
# 2025-03-20 11:00:16,510 - INFO -   Accession Number: 0000842162-24-000030
# 2025-03-20 11:00:21,286 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:00:21,293 - INFO - Already downloaded: LEA_20240430_000084216224000030_8K.json
# 2025-03-20 11:00:21,294 - INFO - Processing filing data for 2024-02-20 - LEA
# 2025-03-20 11:00:21,294 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/842162/000084216224000013/0000842162-24-000013-index.htm
# 2025-03-20 11:00:21,294 - INFO -   Accession Number: 0000842162-24-000013
# 2025-03-20 11:00:25,047 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:00:25,051 - INFO - Already downloaded: LEA_20240220_000084216224000013_8K.json
# 2025-03-20 11:00:25,052 - INFO - Processing filing data for 2024-02-06 - LEA
# 2025-03-20 11:00:25,052 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/842162/000084216224000005/0000842162-24-000005-index.htm
# 2025-03-20 11:00:25,052 - INFO -   Accession Number: 0000842162-24-000005
# 2025-03-20 11:00:29,527 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:00:29,539 - INFO - Downloaded LEA_20240206_000084216224000005_8K.json (7/7)
# 2025-03-20 11:00:29,539 - INFO - Completed LEA  - Downloaded 7 filings
# 2025-03-20 11:00:29,540 - INFO - Progress: 1314/9720 companies processed (13.5%)
# 2025-03-20 11:00:29,541 - INFO - S&P 500 companies: 96/96
# 2025-03-20 11:00:29,542 - INFO - Other companies: 1218/9624
# 2025-03-20 11:00:29,542 - INFO - Total documents downloaded: 272
# 2025-03-20 11:00:29,542 - INFO - Estimated time remaining: 2 hours, 51 minutes
# 2025-03-20 11:00:29,542 - INFO - Waiting 3.50 seconds before next company...
# 2025-03-20 11:00:33,045 - INFO -
# Processing PHI  (CIK 78150)
# 2025-03-20 11:00:33,046 - INFO - Requesting ATOM feed for PHI  (CIK 78150)...
# 2025-03-20 11:00:35,351 - INFO - Found 0 8-K filings from 2024 for PHI
# 2025-03-20 11:00:35,352 - INFO - Retry 1/3 for PHI
# 2025-03-20 11:00:44,348 - INFO - Requesting ATOM feed for PHI  (CIK 78150)...
# 2025-03-20 11:00:47,009 - INFO - Found 0 8-K filings from 2024 for PHI
# 2025-03-20 11:00:47,009 - INFO - Retry 2/3 for PHI
# 2025-03-20 11:00:55,167 - INFO - Requesting ATOM feed for PHI  (CIK 78150)...
# 2025-03-20 11:01:03,644 - INFO - Found 0 8-K filings from 2024 for PHI
# 2025-03-20 11:01:03,645 - WARNING - No filings found for PHI after 3 attempts
# 2025-03-20 11:01:03,645 - INFO -
# Processing FMC  (CIK 37785)
# 2025-03-20 11:01:03,645 - INFO - Requesting ATOM feed for FMC  (CIK 37785)...
# 2025-03-20 11:01:06,636 - INFO - Found 7 8-K filings from 2024 for FMC
# 2025-03-20 11:01:06,637 - INFO - Processing filing data for 2024-12-12 - FMC
# 2025-03-20 11:01:06,638 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/37785/000003778524000128/0000037785-24-000128-index.htm
# 2025-03-20 11:01:06,638 - INFO -   Accession Number: 0000037785-24-000128
# 2025-03-20 11:01:10,819 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:10,825 - INFO - Downloaded FMC_20241212_000003778524000128_8K.json (1/7)
# 2025-03-20 11:01:10,825 - INFO - Processing filing data for 2024-12-11 - FMC
# 2025-03-20 11:01:10,826 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/37785/000003778524000125/0000037785-24-000125-index.htm
# 2025-03-20 11:01:10,826 - INFO -   Accession Number: 0000037785-24-000125
# 2025-03-20 11:01:14,526 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:14,535 - INFO - Downloaded FMC_20241211_000003778524000125_8K.json (2/7)
# 2025-03-20 11:01:14,535 - INFO - Processing filing data for 2024-10-29 - FMC
# 2025-03-20 11:01:14,536 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/37785/000003778524000112/0000037785-24-000112-index.htm
# 2025-03-20 11:01:14,536 - INFO -   Accession Number: 0000037785-24-000112
# 2025-03-20 11:01:19,724 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:19,738 - INFO - Downloaded FMC_20241029_000003778524000112_8K.json (3/7)
# 2025-03-20 11:01:19,739 - INFO - Processing filing data for 2024-07-31 - FMC
# 2025-03-20 11:01:19,739 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/37785/000003778524000098/0000037785-24-000098-index.htm
# 2025-03-20 11:01:19,740 - INFO -   Accession Number: 0000037785-24-000098
# 2025-03-20 11:01:23,166 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:23,181 - INFO - Downloaded FMC_20240731_000003778524000098_8K.json (4/7)
# 2025-03-20 11:01:23,181 - INFO - Processing filing data for 2024-07-15 - FMC
# 2025-03-20 11:01:23,182 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/37785/000003778524000083/0000037785-24-000083-index.htm
# 2025-03-20 11:01:23,182 - INFO -   Accession Number: 0000037785-24-000083
# 2025-03-20 11:01:26,816 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:26,824 - INFO - Downloaded FMC_20240715_000003778524000083_8K.json (5/7)
# 2025-03-20 11:01:26,824 - INFO - Processing filing data for 2024-07-12 - FMC
# 2025-03-20 11:01:26,825 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/37785/000003778524000081/0000037785-24-000081-index.htm
# 2025-03-20 11:01:26,825 - INFO -   Accession Number: 0000037785-24-000081
# 2025-03-20 11:01:30,196 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:30,204 - INFO - Downloaded FMC_20240712_000003778524000081_8K.json (6/7)
# 2025-03-20 11:01:30,204 - INFO - Processing filing data for 2024-06-11 - FMC
# 2025-03-20 11:01:30,204 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/37785/000003778524000070/0000037785-24-000070-index.htm
# 2025-03-20 11:01:30,205 - INFO -   Accession Number: 0000037785-24-000070
# 2025-03-20 11:01:35,432 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:35,444 - INFO - Downloaded FMC_20240611_000003778524000070_8K.json (7/7)
# 2025-03-20 11:01:35,445 - INFO - Completed FMC  - Downloaded 7 filings
# 2025-03-20 11:01:35,445 - INFO - Progress: 1316/9720 companies processed (13.5%)
# 2025-03-20 11:01:35,446 - INFO - S&P 500 companies: 96/96
# 2025-03-20 11:01:35,447 - INFO - Other companies: 1220/9624
# 2025-03-20 11:01:35,447 - INFO - Total documents downloaded: 279
# 2025-03-20 11:01:35,447 - INFO - Estimated time remaining: 2 hours, 58 minutes
# 2025-03-20 11:01:35,448 - INFO - Waiting 3.23 seconds before next company...
# 2025-03-20 11:01:38,683 - INFO -
# Processing CMC  (CIK 22444)
# 2025-03-20 11:01:38,684 - INFO - Requesting ATOM feed for CMC  (CIK 22444)...
# 2025-03-20 11:01:41,361 - INFO - Found 5 8-K filings from 2024 for CMC
# 2025-03-20 11:01:41,361 - INFO - Processing filing data for 2024-11-06 - CMC
# 2025-03-20 11:01:41,362 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/22444/000119312524252071/0001193125-24-252071-index.htm
# 2025-03-20 11:01:41,362 - INFO -   Accession Number: 0001193125-24-252071
# 2025-03-20 11:01:44,995 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:45,001 - INFO - Downloaded CMC_20241106_000119312524252071_8K.json (1/5)
# 2025-03-20 11:01:45,001 - INFO - Processing filing data for 2024-10-31 - CMC
# 2025-03-20 11:01:45,002 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/22444/000119312524248729/0001193125-24-248729-index.htm
# 2025-03-20 11:01:45,002 - INFO -   Accession Number: 0001193125-24-248729
# 2025-03-20 11:01:48,172 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:48,179 - INFO - Downloaded CMC_20241031_000119312524248729_8K.json (2/5)
# 2025-03-20 11:01:48,180 - INFO - Processing filing data for 2024-10-17 - CMC
# 2025-03-20 11:01:48,180 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/22444/000002244424000137/0000022444-24-000137-index.htm
# 2025-03-20 11:01:48,180 - INFO -   Accession Number: 0000022444-24-000137
# 2025-03-20 11:01:53,757 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:53,852 - INFO - Downloaded CMC_20241017_000002244424000137_8K.json (3/5)
# 2025-03-20 11:01:53,853 - INFO - Processing filing data for 2024-10-15 - CMC
# 2025-03-20 11:01:53,853 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/22444/000002244424000119/0000022444-24-000119-index.htm
# 2025-03-20 11:01:53,853 - INFO -   Accession Number: 0000022444-24-000119
# 2025-03-20 11:01:56,753 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:01:56,758 - INFO - Downloaded CMC_20241015_000002244424000119_8K.json (4/5)
# 2025-03-20 11:01:56,759 - INFO - Processing filing data for 2024-10-01 - CMC
# 2025-03-20 11:01:56,759 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/22444/000119312524230258/0001193125-24-230258-index.htm
# 2025-03-20 11:01:56,760 - INFO -   Accession Number: 0001193125-24-230258
# 2025-03-20 11:02:00,525 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:02:00,531 - INFO - Downloaded CMC_20241001_000119312524230258_8K.json (5/5)
# 2025-03-20 11:02:00,532 - INFO - Completed CMC  - Downloaded 5 filings
# 2025-03-20 11:02:00,532 - INFO - Progress: 1317/9720 companies processed (13.5%)
# 2025-03-20 11:02:00,533 - INFO - S&P 500 companies: 96/96
# 2025-03-20 11:02:00,534 - INFO - Other companies: 1221/9624
# 2025-03-20 11:02:00,534 - INFO - Total documents downloaded: 284
# 2025-03-20 11:02:00,535 - INFO - Estimated time remaining: 3 hours, 0 minutes
# 2025-03-20 11:02:00,535 - INFO - Waiting 3.82 seconds before next company...
# 2025-03-20 11:02:04,361 - INFO -
# Processing GBCI  (CIK 868671)
# 2025-03-20 11:02:04,361 - INFO - Requesting ATOM feed for GBCI  (CIK 868671)...
# 2025-03-20 11:02:06,433 - INFO - Found 6 8-K filings from 2024 for GBCI
# 2025-03-20 11:02:06,434 - INFO - Processing filing data for 2024-11-18 - GBCI
# 2025-03-20 11:02:06,434 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/868671/000086867124000106/0000868671-24-000106-index.htm
# 2025-03-20 11:02:06,434 - INFO -   Accession Number: 0000868671-24-000106
# 2025-03-20 11:02:10,855 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:02:10,967 - INFO - Downloaded GBCI_20241118_000086867124000106_8K.json (1/6)
# 2025-03-20 11:02:10,968 - INFO - Processing filing data for 2024-11-05 - GBCI
# 2025-03-20 11:02:10,968 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/868671/000086867124000102/0000868671-24-000102-index.htm
# 2025-03-20 11:02:10,969 - INFO -   Accession Number: 0000868671-24-000102
# 2025-03-20 11:02:14,912 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:02:14,918 - INFO - Downloaded GBCI_20241105_000086867124000102_8K.json (2/6)
# 2025-03-20 11:02:14,919 - INFO - Processing filing data for 2024-11-04 - GBCI
# 2025-03-20 11:02:14,919 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/868671/000086867124000097/0000868671-24-000097-index.htm
# 2025-03-20 11:02:14,920 - INFO -   Accession Number: 0000868671-24-000097
# 2025-03-20 11:02:19,442 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:02:19,447 - INFO - Downloaded GBCI_20241104_000086867124000097_8K.json (3/6)
# 2025-03-20 11:02:19,448 - INFO - Processing filing data for 2024-10-24 - GBCI
# 2025-03-20 11:02:19,448 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/868671/000086867124000089/0000868671-24-000089-index.htm
# 2025-03-20 11:02:19,448 - INFO -   Accession Number: 0000868671-24-000089
# 2025-03-20 11:02:25,065 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:02:25,095 - INFO - Downloaded GBCI_20241024_000086867124000089_8K.json (4/6)
# 2025-03-20 11:02:25,096 - INFO - Processing filing data for 2024-08-14 - GBCI
# 2025-03-20 11:02:25,096 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/868671/000086867124000086/0000868671-24-000086-index.htm
# 2025-03-20 11:02:25,097 - INFO -   Accession Number: 0000868671-24-000086
# 2025-03-20 11:02:29,133 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:02:29,238 - INFO - Downloaded GBCI_20240814_000086867124000086_8K.json (5/6)
# 2025-03-20 11:02:29,238 - INFO - Processing filing data for 2024-07-22 - GBCI
# 2025-03-20 11:02:29,238 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/868671/000086867124000073/0000868671-24-000073-index.htm
# 2025-03-20 11:02:29,239 - INFO -   Accession Number: 0000868671-24-000073
# 2025-03-20 11:02:34,995 - INFO -   Successfully retrieved full text submission
# 2025-03-20 11:02:35,011 - INFO - Downloaded GBCI_20240722_000086867124000073_8K.json (6/6)
# 2025-03-20 11:02:35,011 - INFO - Completed GBCI  - Downloaded 6 filings
# 2025-03-20 11:02:35,011 - INFO - Progress: 1318/9720 companies processed (13.6%)
# 2025-03-20 11:02:35,012 - INFO - S&P 500 companies: 96/96
# 2025-03-20 11:02:35,013 - INFO - Other companies: 1222/9624
# 2025-03-20 11:02:35,013 - INFO - Total documents downloaded: 290
# 2025-03-20 11:02:35,013 - INFO - Estimated time remaining: 3 hours, 4 minutes
# 2025-03-20 11:02:35,014 - INFO - Waiting 7.66 seconds before next company...
# 2025-03-20 11:02:42,677 - INFO -
# Processing CUYTY  (CIK 1437153)
# 2025-03-20 11:02:42,678 - INFO - Requesting ATOM feed for CUYTY  (CIK 1437153)...
# 2025-03-20 11:02:44,753 - INFO - Found 0 8-K filings from 2024 for CUYTY
# 2025-03-20 11:02:44,754 - INFO - Retry 1/3 for CUYTY
# 2025-03-20 11:02:52,678 - INFO - Requesting ATOM feed for CUYTY  (CIK 1437153)...
# 2025-03-20 11:02:55,151 - INFO - Found 0 8-K filings from 2024 for CUYTY
# 2025-03-20 11:02:55,151 - INFO - Retry 2/3 for CUYTY
# 2025-03-20 11:03:02,790 - INFO - Requesting ATOM feed for CUYTY  (CIK 1437153)...
# 2025-03-20 11:03:05,785 - INFO - Found 0 8-K filings from 2024 for CUYTY
# 2025-03-20 11:03:05,786 - WARNING - No filings found for CUYTY after 3 attempts
# 2025-03-20 11:03:05,787 - INFO -
# Processing PAM  (CIK 1469395)
# 2025-03-20 11:03:05,787 - INFO - Requesting ATOM feed for PAM  (CIK 1469395)...
# 2025-03-20 11:03:12,850 - INFO - Found 0 8-K filings from 2024 for PAM
# 2025-03-20 11:03:12,850 - INFO - Retry 1/3 for PAM
# 2025-03-20 11:03:21,585 - INFO - Requesting ATOM feed for PAM  (CIK 1469395)...
# 2025-03-20 11:03:23,913 - INFO - Found 0 8-K filings from 2024 for PAM
# 2025-03-20 11:03:23,913 - INFO - Retry 2/3 for PAM
# 2025-03-20 11:03:32,637 - INFO - Requesting ATOM feed for PAM  (CIK 1469395)...
# 2025-03-20 11:03:36,046 - INFO - Found 0 8-K filings from 2024 for PAM
# 2025-03-20 11:03:36,047 - WARNING - No filings found for PAM after 3 attempts
# 2025-03-20 11:03:36,048 - INFO -
# Processing MTH  (CIK 833079)
# 2025-03-20 11:03:36,048 - INFO - Requesting ATOM feed for MTH  (CIK 833079)...
# 2025-03-20 11:03:38,996 - INFO - Found 6 8-K filings from 2024 for MTH
# 2025-03-20 11:03:38,997 - INFO - Processing filing data for 2024-10-29 - MTH
# 2025-03-20 11:03:38,997 - INFO -   URL: https://www.sec.gov/Archives/edgar/data/833079/000083307924000118/0000833079-24-000118-index.htm
# 2025-03-20 11:03:38,998 - INFO -   Accession Number: 0000833079-24-000118
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 835
#     832         logger.info(f"Metadata saved to 8k_filings.csv")
#     834 if __name__ == "__main__":
# --> 835     main()
#
# Cell In[1], line 747, in main()
#     744 filing_date = filing['date']
#     746 # Get filing details with improved error handling
# --> 747 filing_data, clean_id = get_filing_details(filing)
#     749 if not filing_data or not clean_id:
#     750     logger.warning(f"Failed to get filing data/ID for {ticker or company_name} filing on {filing_date}")
#
# Cell In[1], line 398, in get_filing_details(filing)
#     395     clean_id = filing_id.replace(' ', '_').replace('-', '_')
#     397 # Random delay before request
# --> 398 time.sleep(random.uniform(MIN_DELAY, MAX_DELAY))
#     400 try:
#     401     # First get the filing detail page
#     402     detail_response = requests.get(filing_url, headers=get_headers())
#
# KeyboardInterrupt:
